# %% [markdown]
# # **Step 1: Set Up the Environment**

# %%
# Import required libraries
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os

# %%
# Load the datasets
file_paths = {
    "all_data_1": "all_data_1.csv",
    "all_data_2": "all_data_2.csv",
    "all_data_3": "all_data_3.csv",
    "all_data_4": "all_data_4.csv",
    "all_data_5": "all_data_5.csv",
    "all_data_6": "all_data_6.csv",
    "all_data_7": "all_data_7.csv",
    "all_data_8": "all_data_8.csv",
    "all_data_9": "all_data_9.csv",
    "all_data_10": "all_data_10.csv",
    "all_data_11": "all_data_11.csv",
    "all_data_12": "all_data_12.csv",
    "all_data_13": "all_data_13.csv",
    "all_data_14": "all_data_14.csv",
    "all_data_15": "all_data_15.csv",
    "all_data_16": "all_data_16.csv",
    "all_data_17": "all_data_17.csv",
    "all_data_18": "all_data_18.csv",
    "all_data_19": "all_data_19.csv",
    "all_data_20": "all_data_20.csv",
    "all_data_21": "all_data_21.csv",
    "all_data_22": "all_data_22.csv",
    "all_data_23": "all_data_23.csv",
    "all_data_24": "all_data_24.csv",
    "all_data_25": "all_data_25.csv",
    "all_data_26": "all_data_26.csv",
    "all_data_27": "all_data_27.csv",
    "all_data_28": "all_data_28.csv",
    "all_data_29": "all_data_29.csv",
    "all_data_30": "all_data_30.csv",
    "all_data_31": "all_data_31.csv",
    "all_data_32": "all_data_32.csv",
    "all_data_33": "all_data_33.csv",
    "all_data_34": "all_data_34.csv",
    "all_data_35": "all_data_35.csv",
    "all_data_36": "all_data_36.csv",
    "all_data_37": "all_data_37.csv",
    "all_data_38": "all_data_38.csv",
    "all_data_39": "all_data_39.csv",
    "all_data_40": "all_data_40.csv",
    "all_data_41": "all_data_41.csv",
    "all_data_42": "all_data_42.csv",
    "all_data_43": "all_data_43.csv",
    "all_data_44": "all_data_44.csv",
    "all_data_45": "all_data_45.csv",
    "all_data_46": "all_data_46.csv",
    "all_data_47": "all_data_47.csv",
    "all_data_48": "all_data_48.csv",
    "all_data_49": "all_data_49.csv",
    "all_data_50": "all_data_50.csv",
}

# %%
# Load the datasets into pandas DataFrames
datasets = {name: pd.read_csv(path) for name, path in file_paths.items()}

# %% [markdown]
# # **Step 2: Preprocessing**
#
# ❗❗❗ **Do not forget to change the sensor_columns (depends on the dataset)!** ❗❗❗

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd

# %%
# Combine datasets
combined_data = pd.concat([datasets[f"all_data_{i}"] for i in range(1, 51)], ignore_index=True)

# Filter out noise
filtered_data = combined_data[combined_data["Letter"] != "noise"]

# Define sensor columns
sensor_columns = ['Acc_X', 'Acc_Y', 'Acc_Z', 'Gyro_X', 'Gyro_Y', 'Gyro_Z', 'Mag_X', 'Mag_Y', 'Mag_Z', 'Force']

# Normalize sensor data (Z-score normalization)
scaler = StandardScaler()
filtered_data[sensor_columns] = scaler.fit_transform(filtered_data[sensor_columns])
# Out:
# <ipython-input-5-87109f372068>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data[sensor_columns] = scaler.fit_transform(filtered_data[sensor_columns])

# %%
# Function to group data into sequences by label
def create_sequences(data):
    sequences = []
    labels = []
    current_label = None
    current_sequence = []

    for _, row in data.iterrows():
        if row["Letter"] != current_label:
            # Save the current sequence if it's not empty
            if current_sequence:
                sequences.append(np.array(current_sequence))
                labels.append(current_label)
            # Start a new sequence
            current_label = row["Letter"]
            current_sequence = []

        # Append sensor values to the current sequence
        current_sequence.append(row[sensor_columns].values)

    # Save the final sequence
    if current_sequence:
        sequences.append(np.array(current_sequence))
        labels.append(current_label)

    return np.array(sequences, dtype=object), labels

# %%
# prompt: shape of sequences and labels

# Create sequences and labels
sequences, labels = create_sequences(filtered_data)

# Print the shapes
print("Sequences shape:", sequences.shape)
print("Labels shape:", len(labels))

for seq, label in zip(sequences, labels):
    print(f"Sequence Shape: {seq.shape}, Label: {label}")
# Out:
# Sequences shape: (3094,)
# Labels shape: 3094
# Sequence Shape: (20, 10), Label: A
# Sequence Shape: (20, 10), Label: B
# Sequence Shape: (16, 10), Label: C
# Sequence Shape: (16, 10), Label: D
# Sequence Shape: (15, 10), Label: E
# Sequence Shape: (15, 10), Label: F
# Sequence Shape: (14, 10), Label: G
# Sequence Shape: (11, 10), Label: H
# Sequence Shape: (10, 10), Label: I
# Sequence Shape: (10, 10), Label: J
# Sequence Shape: (10, 10), Label: K
# Sequence Shape: (8, 10), Label: L
# Sequence Shape: (11, 10), Label: M
# Sequence Shape: (10, 10), Label: N
# Sequence Shape: (11, 10), Label: O
# Sequence Shape: (13, 10), Label: P
# Sequence Shape: (12, 10), Label: Q
# Sequence Shape: (11, 10), Label: R
# Sequence Shape: (12, 10), Label: S
# Sequence Shape: (12, 10), Label: T
# Sequence Shape: (16, 10), Label: U
# Sequence Shape: (18, 10), Label: V
# Sequence Shape: (19, 10), Label: W
# Sequence Shape: (14, 10), Label: X
# Sequence Shape: (15, 10), Label: Y
# Sequence Shape: (17, 10), Label: Z
# Sequence Shape: (8, 10), Label: a
# Sequence Shape: (7, 10), Label: b
# Sequence Shape: (7, 10), Label: c
# Sequence Shape: (11, 10), Label: d
# Sequence Shape: (6, 10), Label: e
# Sequence Shape: (9, 10), Label: f
# Sequence Shape: (14, 10), Label: g
# Sequence Shape: (18, 10), Label: h
# Sequence Shape: (8, 10), Label: i
# Sequence Shape: (9, 10), Label: j
# Sequence Shape: (23, 10), Label: k
# Sequence Shape: (19, 10), Label: l
# Sequence Shape: (9, 10), Label: m
# Sequence Shape: (19, 10), Label: n
# Sequence Shape: (16, 10), Label: o
# Sequence Shape: (10, 10), Label: p
# Sequence Shape: (21, 10), Label: q
# Sequence Shape: (9, 10), Label: r
# Sequence Shape: (8, 10), Label: s
# Sequence Shape: (15, 10), Label: t
# Sequence Shape: (7, 10), Label: u
# Sequence Shape: (14, 10), Label: v
# Sequence Shape: (12, 10), Label: w
# Sequence Shape: (16, 10), Label: x
# Sequence Shape: (11, 10), Label: y
# Sequence Shape: (16, 10), Label: z
# Sequence Shape: (16, 10), Label: 0
# Sequence Shape: (6, 10), Label: 1
# Sequence Shape: (7, 10), Label: 2
# Sequence Shape: (13, 10), Label: 3
# Sequence Shape: (9, 10), Label: 4
# Sequence Shape: (12, 10), Label: 5
# Sequence Shape: (13, 10), Label: 6
# Sequence Shape: (14, 10), Label: 7
# Sequence Shape: (21, 10), Label: 8
# Sequence Shape: (19, 10), Label: 9
# Sequence Shape: (18, 10), Label: A
# Sequence Shape: (7, 10), Label: B
# Sequence Shape: (12, 10), Label: C
# Sequence Shape: (19, 10), Label: D
# Sequence Shape: (15, 10), Label: E
# Sequence Shape: (13, 10), Label: F
# Sequence Shape: (11, 10), Label: G
# Sequence Shape: (13, 10), Label: H
# Sequence Shape: (12, 10), Label: I
# Sequence Shape: (9, 10), Label: J
# Sequence Shape: (12, 10), Label: K
# Sequence Shape: (15, 10), Label: L
# Sequence Shape: (11, 10), Label: M
# Sequence Shape: (10, 10), Label: N
# Sequence Shape: (15, 10), Label: O
# Sequence Shape: (11, 10), Label: P
# Sequence Shape: (10, 10), Label: Q
# Sequence Shape: (10, 10), Label: R
# Sequence Shape: (9, 10), Label: S
# Sequence Shape: (14, 10), Label: T
# Sequence Shape: (8, 10), Label: U
# Sequence Shape: (8, 10), Label: V
# Sequence Shape: (13, 10), Label: W
# Sequence Shape: (11, 10), Label: X
# Sequence Shape: (10, 10), Label: Y
# Sequence Shape: (8, 10), Label: Z
# Sequence Shape: (10, 10), Label: a
# Sequence Shape: (7, 10), Label: b
# Sequence Shape: (6, 10), Label: c
# Sequence Shape: (9, 10), Label: d
# Sequence Shape: (6, 10), Label: e
# Sequence Shape: (16, 10), Label: f
# Sequence Shape: (12, 10), Label: g
# Sequence Shape: (18, 10), Label: h
# Sequence Shape: (15, 10), Label: i
# Sequence Shape: (10, 10), Label: j
# Sequence Shape: (8, 10), Label: k
# Sequence Shape: (12, 10), Label: l
# Sequence Shape: (9, 10), Label: m
# Sequence Shape: (7, 10), Label: n
# Sequence Shape: (30, 10), Label: o
# Sequence Shape: (19, 10), Label: p
# Sequence Shape: (25, 10), Label: q
# Sequence Shape: (17, 10), Label: r
# Sequence Shape: (15, 10), Label: s
# Sequence Shape: (19, 10), Label: t
# Sequence Shape: (8, 10), Label: u
# Sequence Shape: (18, 10), Label: v
# Sequence Shape: (10, 10), Label: w
# Sequence Shape: (15, 10), Label: x
# Sequence Shape: (8, 10), Label: y
# Sequence Shape: (16, 10), Label: z
# Sequence Shape: (29, 10), Label: 0
# Sequence Shape: (14, 10), Label: 1
# Sequence Shape: (18, 10), Label: 2
# Sequence Shape: (9, 10), Label: 3
# Sequence Shape: (15, 10), Label: 4
# Sequence Shape: (19, 10), Label: 5
# Sequence Shape: (13, 10), Label: 6
# Sequence Shape: (14, 10), Label: 7
# Sequence Shape: (15, 10), Label: 8
# Sequence Shape: (10, 10), Label: 9
# Sequence Shape: (21, 10), Label: A
# Sequence Shape: (21, 10), Label: B
# Sequence Shape: (17, 10), Label: C
# Sequence Shape: (18, 10), Label: D
# Sequence Shape: (26, 10), Label: E
# Sequence Shape: (24, 10), Label: F
# Sequence Shape: (33, 10), Label: G
# Sequence Shape: (22, 10), Label: H
# Sequence Shape: (24, 10), Label: I
# Sequence Shape: (9, 10), Label: J
# Sequence Shape: (25, 10), Label: K
# Sequence Shape: (11, 10), Label: L
# Sequence Shape: (14, 10), Label: M
# Sequence Shape: (17, 10), Label: O
# Sequence Shape: (16, 10), Label: P
# Sequence Shape: (13, 10), Label: Q
# Sequence Shape: (18, 10), Label: R
# Sequence Shape: (11, 10), Label: S
# Sequence Shape: (12, 10), Label: T
# Sequence Shape: (17, 10), Label: U
# Sequence Shape: (9, 10), Label: V
# Sequence Shape: (12, 10), Label: W
# Sequence Shape: (18, 10), Label: X
# Sequence Shape: (15, 10), Label: Y
# Sequence Shape: (16, 10), Label: Z
# Sequence Shape: (29, 10), Label: a
# Sequence Shape: (14, 10), Label: b
# Sequence Shape: (12, 10), Label: c
# Sequence Shape: (11, 10), Label: d
# Sequence Shape: (14, 10), Label: e
# Sequence Shape: (15, 10), Label: f
# Sequence Shape: (12, 10), Label: g
# Sequence Shape: (10, 10), Label: h
# Sequence Shape: (13, 10), Label: i
# Sequence Shape: (19, 10), Label: j
# Sequence Shape: (30, 10), Label: k
# Sequence Shape: (13, 10), Label: l
# Sequence Shape: (17, 10), Label: m
# Sequence Shape: (15, 10), Label: n
# Sequence Shape: (13, 10), Label: o
# Sequence Shape: (16, 10), Label: p
# Sequence Shape: (17, 10), Label: q
# Sequence Shape: (14, 10), Label: r
# Sequence Shape: (13, 10), Label: s
# Sequence Shape: (17, 10), Label: t
# Sequence Shape: (13, 10), Label: u
# Sequence Shape: (9, 10), Label: v
# Sequence Shape: (13, 10), Label: w
# Sequence Shape: (15, 10), Label: x
# Sequence Shape: (13, 10), Label: y
# Sequence Shape: (24, 10), Label: z
# Sequence Shape: (16, 10), Label: 1
# Sequence Shape: (16, 10), Label: 2
# Sequence Shape: (14, 10), Label: 3
# Sequence Shape: (15, 10), Label: 4
# Sequence Shape: (19, 10), Label: 5
# Sequence Shape: (15, 10), Label: 6
# Sequence Shape: (15, 10), Label: 7
# Sequence Shape: (10, 10), Label: 8
# Sequence Shape: (12, 10), Label: 9
# Sequence Shape: (27, 10), Label: A
# Sequence Shape: (22, 10), Label: B
# Sequence Shape: (18, 10), Label: C
# Sequence Shape: (18, 10), Label: D
# Sequence Shape: (21, 10), Label: E
# Sequence Shape: (24, 10), Label: F
# Sequence Shape: (18, 10), Label: G
# Sequence Shape: (19, 10), Label: H
# Sequence Shape: (19, 10), Label: I
# Sequence Shape: (18, 10), Label: J
# Sequence Shape: (15, 10), Label: K
# Sequence Shape: (17, 10), Label: L
# Sequence Shape: (25, 10), Label: M
# Sequence Shape: (16, 10), Label: N
# Sequence Shape: (15, 10), Label: O
# Sequence Shape: (14, 10), Label: P
# Sequence Shape: (14, 10), Label: Q
# Sequence Shape: (15, 10), Label: R
# Sequence Shape: (11, 10), Label: S
# Sequence Shape: (14, 10), Label: T
# Sequence Shape: (12, 10), Label: U
# Sequence Shape: (13, 10), Label: V
# Sequence Shape: (15, 10), Label: W
# Sequence Shape: (14, 10), Label: X
# Sequence Shape: (18, 10), Label: Y
# Sequence Shape: (22, 10), Label: Z
# Sequence Shape: (19, 10), Label: a
# Sequence Shape: (12, 10), Label: b
# Sequence Shape: (11, 10), Label: c
# Sequence Shape: (11, 10), Label: d
# Sequence Shape: (10, 10), Label: e
# Sequence Shape: (13, 10), Label: f
# Sequence Shape: (11, 10), Label: g
# Sequence Shape: (10, 10), Label: h
# Sequence Shape: (11, 10), Label: i
# Sequence Shape: (12, 10), Label: j
# Sequence Shape: (12, 10), Label: k
# Sequence Shape: (14, 10), Label: l
# Sequence Shape: (14, 10), Label: m
# Sequence Shape: (11, 10), Label: n
# Sequence Shape: (11, 10), Label: o
# Sequence Shape: (17, 10), Label: p
# Sequence Shape: (24, 10), Label: q
# Sequence Shape: (30, 10), Label: r
# Sequence Shape: (11, 10), Label: s
# Sequence Shape: (20, 10), Label: t
# Sequence Shape: (17, 10), Label: u
# Sequence Shape: (17, 10), Label: v
# Sequence Shape: (19, 10), Label: w
# Sequence Shape: (17, 10), Label: x
# Sequence Shape: (11, 10), Label: y
# Sequence Shape: (31, 10), Label: z
# Sequence Shape: (16, 10), Label: 0
# Sequence Shape: (14, 10), Label: 1
# Sequence Shape: (24, 10), Label: 2
# Sequence Shape: (18, 10), Label: 3
# Sequence Shape: (16, 10), Label: 4
# Sequence Shape: (18, 10), Label: 5
# Sequence Shape: (14, 10), Label: 6
# Sequence Shape: (14, 10), Label: 7
# Sequence Shape: (14, 10), Label: 8
# Sequence Shape: (15, 10), Label: 9
# Sequence Shape: (24, 10), Label: A
# Sequence Shape: (19, 10), Label: B
# Sequence Shape: (11, 10), Label: C
# Sequence Shape: (13, 10), Label: D
# Sequence Shape: (35, 10), Label: E
# Sequence Shape: (18, 10), Label: F
# Sequence Shape: (11, 10), Label: G
# Sequence Shape: (18, 10), Label: H
# Sequence Shape: (17, 10), Label: I
# Sequence Shape: (22, 10), Label: J
# Sequence Shape: (25, 10), Label: K
# Sequence Shape: (15, 10), Label: L
# Sequence Shape: (17, 10), Label: M
# Sequence Shape: (23, 10), Label: N
# Sequence Shape: (14, 10), Label: O
# Sequence Shape: (15, 10), Label: P
# Sequence Shape: (16, 10), Label: Q
# Sequence Shape: (17, 10), Label: R
# Sequence Shape: (16, 10), Label: S
# Sequence Shape: (14, 10), Label: T
# Sequence Shape: (14, 10), Label: U
# Sequence Shape: (26, 10), Label: V
# Sequence Shape: (17, 10), Label: W
# Sequence Shape: (17, 10), Label: X
# Sequence Shape: (16, 10), Label: Y
# Sequence Shape: (19, 10), Label: Z
# Sequence Shape: (21, 10), Label: a
# Sequence Shape: (16, 10), Label: b
# Sequence Shape: (14, 10), Label: c
# Sequence Shape: (15, 10), Label: d
# Sequence Shape: (15, 10), Label: e
# Sequence Shape: (19, 10), Label: f
# Sequence Shape: (14, 10), Label: g
# Sequence Shape: (20, 10), Label: h
# Sequence Shape: (9, 10), Label: i
# Sequence Shape: (8, 10), Label: j
# Sequence Shape: (14, 10), Label: k
# Sequence Shape: (14, 10), Label: l
# Sequence Shape: (15, 10), Label: m
# Sequence Shape: (18, 10), Label: n
# Sequence Shape: (13, 10), Label: o
# Sequence Shape: (13, 10), Label: p
# Sequence Shape: (13, 10), Label: q
# Sequence Shape: (16, 10), Label: r
# Sequence Shape: (17, 10), Label: s
# Sequence Shape: (17, 10), Label: t
# Sequence Shape: (16, 10), Label: u
# Sequence Shape: (15, 10), Label: v
# Sequence Shape: (24, 10), Label: w
# Sequence Shape: (18, 10), Label: x
# Sequence Shape: (15, 10), Label: y
# Sequence Shape: (16, 10), Label: z
# Sequence Shape: (13, 10), Label: 0
# Sequence Shape: (14, 10), Label: 1
# Sequence Shape: (13, 10), Label: 2
# Sequence Shape: (10, 10), Label: 3
# Sequence Shape: (16, 10), Label: 4
# Sequence Shape: (14, 10), Label: 5
# Sequence Shape: (12, 10), Label: 6
# Sequence Shape: (14, 10), Label: 7
# Sequence Shape: (7, 10), Label: 8
# Sequence Shape: (14, 10), Label: 9
# Sequence Shape: (28, 10), Label: B
# Sequence Shape: (18, 10), Label: C
# Sequence Shape: (16, 10), Label: D
# Sequence Shape: (25, 10), Label: E
# Sequence Shape: (20, 10), Label: F
# Sequence Shape: (16, 10), Label: G
# Sequence Shape: (17, 10), Label: H
# Sequence Shape: (20, 10), Label: I
# Sequence Shape: (15, 10), Label: J
# Sequence Shape: (18, 10), Label: K
# Sequence Shape: (14, 10), Label: L
# Sequence Shape: (19, 10), Label: M
# Sequence Shape: (17, 10), Label: N
# Sequence Shape: (14, 10), Label: O
# Sequence Shape: (16, 10), Label: P
# Sequence Shape: (23, 10), Label: Q
# Sequence Shape: (18, 10), Label: R
# Sequence Shape: (16, 10), Label: S
# Sequence Shape: (18, 10), Label: T
# Sequence Shape: (18, 10), Label: U
# Sequence Shape: (14, 10), Label: V
# Sequence Shape: (16, 10), Label: W
# Sequence Shape: (13, 10), Label: X
# Sequence Shape: (12, 10), Label: Y
# Sequence Shape: (17, 10), Label: Z
# Sequence Shape: (16, 10), Label: a
# Sequence Shape: (17, 10), Label: b
# Sequence Shape: (13, 10), Label: c
# Sequence Shape: (10, 10), Label: d
# Sequence Shape: (9, 10), Label: e
# Sequence Shape: (10, 10), Label: f
# Sequence Shape: (10, 10), Label: g
# Sequence Shape: (9, 10), Label: h
# Sequence Shape: (14, 10), Label: i
# Sequence Shape: (11, 10), Label: j
# Sequence Shape: (11, 10), Label: k
# Sequence Shape: (7, 10), Label: l
# Sequence Shape: (11, 10), Label: m
# Sequence Shape: (14, 10), Label: n
# Sequence Shape: (14, 10), Label: o
# Sequence Shape: (10, 10), Label: p
# Sequence Shape: (10, 10), Label: q
# Sequence Shape: (7, 10), Label: r
# Sequence Shape: (9, 10), Label: s
# Sequence Shape: (9, 10), Label: t
# Sequence Shape: (8, 10), Label: u
# Sequence Shape: (16, 10), Label: v
# Sequence Shape: (12, 10), Label: w
# Sequence Shape: (16, 10), Label: x
# Sequence Shape: (11, 10), Label: y
# Sequence Shape: (12, 10), Label: z
# Sequence Shape: (14, 10), Label: 0
# Sequence Shape: (8, 10), Label: 1
# Sequence Shape: (8, 10), Label: 2
# Sequence Shape: (8, 10), Label: 3
# Sequence Shape: (11, 10), Label: 4
# Sequence Shape: (10, 10), Label: 5
# Sequence Shape: (14, 10), Label: 6
# Sequence Shape: (15, 10), Label: 7
# Sequence Shape: (14, 10), Label: 8
# Sequence Shape: (20, 10), Label: 9
# Sequence Shape: (48, 10), Label: A
# Sequence Shape: (19, 10), Label: B
# Sequence Shape: (15, 10), Label: C
# Sequence Shape: (12, 10), Label: D
# Sequence Shape: (15, 10), Label: E
# Sequence Shape: (13, 10), Label: F
# Sequence Shape: (13, 10), Label: G
# Sequence Shape: (14, 10), Label: H
# Sequence Shape: (13, 10), Label: I
# Sequence Shape: (11, 10), Label: J
# Sequence Shape: (17, 10), Label: K
# Sequence Shape: (9, 10), Label: L
# Sequence Shape: (11, 10), Label: M
# Sequence Shape: (11, 10), Label: N
# Sequence Shape: (9, 10), Label: O
# Sequence Shape: (16, 10), Label: P
# Sequence Shape: (11, 10), Label: Q
# Sequence Shape: (10, 10), Label: R
# Sequence Shape: (9, 10), Label: S
# Sequence Shape: (10, 10), Label: T
# Sequence Shape: (10, 10), Label: U
# Sequence Shape: (16, 10), Label: V
# Sequence Shape: (12, 10), Label: W
# Sequence Shape: (5, 10), Label: X
# Sequence Shape: (17, 10), Label: Y
# Sequence Shape: (12, 10), Label: Z
# Sequence Shape: (10, 10), Label: a
# Sequence Shape: (9, 10), Label: b
# Sequence Shape: (13, 10), Label: c
# Sequence Shape: (8, 10), Label: d
# Sequence Shape: (12, 10), Label: e
# Sequence Shape: (9, 10), Label: f
# Sequence Shape: (8, 10), Label: g
# Sequence Shape: (9, 10), Label: h
# Sequence Shape: (12, 10), Label: i
# Sequence Shape: (8, 10), Label: j
# Sequence Shape: (11, 10), Label: k
# Sequence Shape: (7, 10), Label: l
# Sequence Shape: (11, 10), Label: m
# Sequence Shape: (10, 10), Label: n
# Sequence Shape: (9, 10), Label: o
# Sequence Shape: (18, 10), Label: p
# Sequence Shape: (9, 10), Label: q
# Sequence Shape: (8, 10), Label: r
# Sequence Shape: (9, 10), Label: s
# Sequence Shape: (12, 10), Label: t
# Sequence Shape: (14, 10), Label: u
# Sequence Shape: (9, 10), Label: v
# Sequence Shape: (11, 10), Label: w
# Sequence Shape: (10, 10), Label: x
# Sequence Shape: (10, 10), Label: y
# Sequence Shape: (15, 10), Label: z
# Sequence Shape: (15, 10), Label: 0
# Sequence Shape: (9, 10), Label: 1
# Sequence Shape: (10, 10), Label: 2
# Sequence Shape: (9, 10), Label: 3
# Sequence Shape: (10, 10), Label: 4
# Sequence Shape: (13, 10), Label: 5
# Sequence Shape: (9, 10), Label: 6
# Sequence Shape: (10, 10), Label: 7
# Sequence Shape: (9, 10), Label: 8
# Sequence Shape: (10, 10), Label: 9
# Sequence Shape: (25, 10), Label: A
# Sequence Shape: (18, 10), Label: B
# Sequence Shape: (8, 10), Label: C
# Sequence Shape: (11, 10), Label: D
# Sequence Shape: (14, 10), Label: E
# Sequence Shape: (11, 10), Label: F
# Sequence Shape: (11, 10), Label: G
# Sequence Shape: (11, 10), Label: H
# Sequence Shape: (13, 10), Label: I
# Sequence Shape: (11, 10), Label: J
# Sequence Shape: (11, 10), Label: K
# Sequence Shape: (10, 10), Label: L
# Sequence Shape: (13, 10), Label: M
# Sequence Shape: (11, 10), Label: N
# Sequence Shape: (13, 10), Label: O
# Sequence Shape: (12, 10), Label: P
# Sequence Shape: (15, 10), Label: Q
# Sequence Shape: (11, 10), Label: R
# Sequence Shape: (10, 10), Label: S
# Sequence Shape: (13, 10), Label: T
# Sequence Shape: (16, 10), Label: U
# Sequence Shape: (10, 10), Label: V
# Sequence Shape: (11, 10), Label: W
# Sequence Shape: (13, 10), Label: X
# Sequence Shape: (13, 10), Label: Y
# Sequence Shape: (10, 10), Label: Z
# Sequence Shape: (14, 10), Label: a
# Sequence Shape: (9, 10), Label: b
# Sequence Shape: (11, 10), Label: c
# Sequence Shape: (8, 10), Label: d
# Sequence Shape: (8, 10), Label: e
# Sequence Shape: (16, 10), Label: f
# Sequence Shape: (10, 10), Label: g
# Sequence Shape: (8, 10), Label: h
# Sequence Shape: (8, 10), Label: i
# Sequence Shape: (9, 10), Label: j
# Sequence Shape: (10, 10), Label: k
# Sequence Shape: (9, 10), Label: l
# Sequence Shape: (10, 10), Label: m
# Sequence Shape: (9, 10), Label: n
# Sequence Shape: (8, 10), Label: o
# Sequence Shape: (16, 10), Label: p
# Sequence Shape: (14, 10), Label: q
# Sequence Shape: (15, 10), Label: r
# Sequence Shape: (13, 10), Label: s
# Sequence Shape: (16, 10), Label: t
# Sequence Shape: (14, 10), Label: u
# Sequence Shape: (18, 10), Label: w
# Sequence Shape: (14, 10), Label: x
# Sequence Shape: (15, 10), Label: y
# Sequence Shape: (16, 10), Label: z
# Sequence Shape: (13, 10), Label: 0
# Sequence Shape: (16, 10), Label: 1
# Sequence Shape: (12, 10), Label: 2
# Sequence Shape: (10, 10), Label: 3
# Sequence Shape: (13, 10), Label: 4
# Sequence Shape: (12, 10), Label: 5
# Sequence Shape: (10, 10), Label: 6
# Sequence Shape: (11, 10), Label: 7
# Sequence Shape: (10, 10), Label: 8
# Sequence Shape: (10, 10), Label: 9
# Sequence Shape: (15, 10), Label: A
# Sequence Shape: (14, 10), Label: B
# Sequence Shape: (10, 10), Label: C
# Sequence Shape: (12, 10), Label: D
# Sequence Shape: (15, 10), Label: E
# Sequence Shape: (11, 10), Label: F
# Sequence Shape: (11, 10), Label: G
# Sequence Shape: (12, 10), Label: H
# Sequence Shape: (11, 10), Label: I
# Sequence Shape: (10, 10), Label: J
# Sequence Shape: (11, 10), Label: K
# Sequence Shape: (11, 10), Label: L
# Sequence Shape: (12, 10), Label: M
# Sequence Shape: (12, 10), Label: N
# Sequence Shape: (11, 10), Label: O
# Sequence Shape: (10, 10), Label: P
# Sequence Shape: (10, 10), Label: Q
# Sequence Shape: (11, 10), Label: R
# Sequence Shape: (8, 10), Label: S
# Sequence Shape: (9, 10), Label: T
# Sequence Shape: (9, 10), Label: U
# Sequence Shape: (9, 10), Label: V
# Sequence Shape: (9, 10), Label: W
# Sequence Shape: (10, 10), Label: X
# Sequence Shape: (9, 10), Label: Y
# Sequence Shape: (28, 10), Label: Z
# Sequence Shape: (16, 10), Label: a
# Sequence Shape: (11, 10), Label: b
# Sequence Shape: (17, 10), Label: c
# Sequence Shape: (15, 10), Label: d
# Sequence Shape: (13, 10), Label: e
# Sequence Shape: (16, 10), Label: f
# Sequence Shape: (10, 10), Label: g
# Sequence Shape: (10, 10), Label: h
# Sequence Shape: (11, 10), Label: i
# Sequence Shape: (9, 10), Label: j
# Sequence Shape: (11, 10), Label: k
# Sequence Shape: (9, 10), Label: l
# Sequence Shape: (13, 10), Label: m
# Sequence Shape: (9, 10), Label: n
# Sequence Shape: (8, 10), Label: o
# Sequence Shape: (9, 10), Label: p
# Sequence Shape: (8, 10), Label: q
# Sequence Shape: (7, 10), Label: r
# Sequence Shape: (8, 10), Label: s
# Sequence Shape: (9, 10), Label: t
# Sequence Shape: (15, 10), Label: u
# Sequence Shape: (8, 10), Label: v
# Sequence Shape: (11, 10), Label: w
# Sequence Shape: (9, 10), Label: x
# Sequence Shape: (9, 10), Label: y
# Sequence Shape: (11, 10), Label: z
# Sequence Shape: (8, 10), Label: 0
# Sequence Shape: (10, 10), Label: 1
# Sequence Shape: (15, 10), Label: 2
# Sequence Shape: (9, 10), Label: 3
# Sequence Shape: (11, 10), Label: 4
# Sequence Shape: (11, 10), Label: 5
# Sequence Shape: (8, 10), Label: 6
# Sequence Shape: (10, 10), Label: 7
# Sequence Shape: (18, 10), Label: 8
# Sequence Shape: (18, 10), Label: 9
# Sequence Shape: (12, 10), Label: A
# Sequence Shape: (12, 10), Label: B
# Sequence Shape: (9, 10), Label: C
# Sequence Shape: (11, 10), Label: D
# Sequence Shape: (14, 10), Label: E
# Sequence Shape: (13, 10), Label: F
# Sequence Shape: (15, 10), Label: G
# Sequence Shape: (12, 10), Label: H
# Sequence Shape: (11, 10), Label: I
# Sequence Shape: (21, 10), Label: J
# Sequence Shape: (27, 10), Label: K
# Sequence Shape: (11, 10), Label: L
# Sequence Shape: (13, 10), Label: M
# Sequence Shape: (25, 10), Label: N
# Sequence Shape: (11, 10), Label: O
# Sequence Shape: (11, 10), Label: P
# Sequence Shape: (11, 10), Label: Q
# Sequence Shape: (16, 10), Label: R
# Sequence Shape: (10, 10), Label: S
# Sequence Shape: (10, 10), Label: T
# Sequence Shape: (9, 10), Label: U
# Sequence Shape: (18, 10), Label: V
# Sequence Shape: (11, 10), Label: W
# Sequence Shape: (10, 10), Label: X
# Sequence Shape: (10, 10), Label: Y
# Sequence Shape: (13, 10), Label: Z
# Sequence Shape: (8, 10), Label: a
# Sequence Shape: (10, 10), Label: b
# Sequence Shape: (9, 10), Label: c
# Sequence Shape: (11, 10), Label: d
# Sequence Shape: (9, 10), Label: e
# Sequence Shape: (10, 10), Label: f
# Sequence Shape: (9, 10), Label: g
# Sequence Shape: (8, 10), Label: h
# Sequence Shape: (10, 10), Label: i
# Sequence Shape: (13, 10), Label: j
# Sequence Shape: (10, 10), Label: k
# Sequence Shape: (10, 10), Label: l
# Sequence Shape: (9, 10), Label: m
# Sequence Shape: (9, 10), Label: n
# Sequence Shape: (10, 10), Label: o
# Sequence Shape: (11, 10), Label: p
# Sequence Shape: (10, 10), Label: q
# Sequence Shape: (27, 10), Label: r
# Sequence Shape: (9, 10), Label: s
# Sequence Shape: (32, 10), Label: t
# Sequence Shape: (10, 10), Label: u
# Sequence Shape: (10, 10), Label: v
# Sequence Shape: (11, 10), Label: w
# Sequence Shape: (10, 10), Label: x
# Sequence Shape: (9, 10), Label: y
# Sequence Shape: (12, 10), Label: z
# Sequence Shape: (10, 10), Label: 0
# Sequence Shape: (14, 10), Label: 1
# Sequence Shape: (10, 10), Label: 2
# Sequence Shape: (9, 10), Label: 3
# Sequence Shape: (11, 10), Label: 4
# Sequence Shape: (19, 10), Label: 5
# Sequence Shape: (9, 10), Label: 6
# Sequence Shape: (10, 10), Label: 7
# Sequence Shape: (10, 10), Label: 8
# Sequence Shape: (17, 10), Label: 9
# Sequence Shape: (14, 10), Label: A
# Sequence Shape: (13, 10), Label: B
# Sequence Shape: (8, 10), Label: C
# Sequence Shape: (11, 10), Label: D
# Sequence Shape: (14, 10), Label: E
# Sequence Shape: (13, 10), Label: F
# Sequence Shape: (11, 10), Label: G
# Sequence Shape: (11, 10), Label: H
# Sequence Shape: (10, 10), Label: I
# Sequence Shape: (10, 10), Label: J
# Sequence Shape: (11, 10), Label: K
# Sequence Shape: (8, 10), Label: L
# Sequence Shape: (11, 10), Label: M
# Sequence Shape: (11, 10), Label: N
# Sequence Shape: (8, 10), Label: O
# Sequence Shape: (12, 10), Label: P
# Sequence Shape: (10, 10), Label: Q
# Sequence Shape: (10, 10), Label: R
# Sequence Shape: (8, 10), Label: S
# Sequence Shape: (10, 10), Label: T
# Sequence Shape: (9, 10), Label: U
# Sequence Shape: (8, 10), Label: V
# Sequence Shape: (9, 10), Label: W
# Sequence Shape: (16, 10), Label: X
# Sequence Shape: (13, 10), Label: Y
# Sequence Shape: (12, 10), Label: Z
# Sequence Shape: (10, 10), Label: a
# Sequence Shape: (9, 10), Label: b
# Sequence Shape: (7, 10), Label: c
# Sequence Shape: (9, 10), Label: d
# Sequence Shape: (18, 10), Label: e
# Sequence Shape: (17, 10), Label: f
# Sequence Shape: (11, 10), Label: g
# Sequence Shape: (18, 10), Label: h
# Sequence Shape: (9, 10), Label: i
# Sequence Shape: (10, 10), Label: j
# Sequence Shape: (21, 10), Label: k
# Sequence Shape: (9, 10), Label: l
# Sequence Shape: (12, 10), Label: m
# Sequence Shape: (9, 10), Label: n
# Sequence Shape: (8, 10), Label: o
# Sequence Shape: (9, 10), Label: p
# Sequence Shape: (8, 10), Label: q
# Sequence Shape: (15, 10), Label: s
# Sequence Shape: (16, 10), Label: t
# Sequence Shape: (15, 10), Label: u
# Sequence Shape: (12, 10), Label: v
# Sequence Shape: (9, 10), Label: w
# Sequence Shape: (9, 10), Label: x
# Sequence Shape: (9, 10), Label: y
# Sequence Shape: (11, 10), Label: z
# Sequence Shape: (9, 10), Label: 0
# Sequence Shape: (10, 10), Label: 1
# Sequence Shape: (9, 10), Label: 2
# Sequence Shape: (8, 10), Label: 3
# Sequence Shape: (9, 10), Label: 4
# Sequence Shape: (10, 10), Label: 5
# Sequence Shape: (15, 10), Label: 6
# Sequence Shape: (13, 10), Label: 7
# Sequence Shape: (18, 10), Label: 8
# Sequence Shape: (9, 10), Label: 9
# Sequence Shape: (22, 10), Label: A
# Sequence Shape: (12, 10), Label: B
# Sequence Shape: (9, 10), Label: C
# Sequence Shape: (10, 10), Label: D
# Sequence Shape: (12, 10), Label: E
# Sequence Shape: (21, 10), Label: F
# Sequence Shape: (13, 10), Label: G
# Sequence Shape: (12, 10), Label: H
# Sequence Shape: (10, 10), Label: I
# Sequence Shape: (10, 10), Label: J
# Sequence Shape: (10, 10), Label: K
# Sequence Shape: (18, 10), Label: L
# Sequence Shape: (12, 10), Label: M
# Sequence Shape: (13, 10), Label: N
# Sequence Shape: (9, 10), Label: O
# Sequence Shape: (10, 10), Label: P
# Sequence Shape: (10, 10), Label: Q
# Sequence Shape: (13, 10), Label: R
# Sequence Shape: (10, 10), Label: S
# Sequence Shape: (10, 10), Label: T
# Sequence Shape: (10, 10), Label: U
# Sequence Shape: (8, 10), Label: V
# Sequence Shape: (10, 10), Label: W
# Sequence Shape: (10, 10), Label: X
# Sequence Shape: (9, 10), Label: Y
# Sequence Shape: (9, 10), Label: Z
# Sequence Shape: (13, 10), Label: a
# Sequence Shape: (12, 10), Label: b
# Sequence Shape: (7, 10), Label: c
# Sequence Shape: (8, 10), Label: d
# Sequence Shape: (7, 10), Label: e
# Sequence Shape: (8, 10), Label: f
# Sequence Shape: (8, 10), Label: g
# Sequence Shape: (7, 10), Label: h
# Sequence Shape: (20, 10), Label: i
# Sequence Shape: (15, 10), Label: j
# Sequence Shape: (10, 10), Label: k
# Sequence Shape: (8, 10), Label: l
# Sequence Shape: (10, 10), Label: m
# Sequence Shape: (8, 10), Label: n
# Sequence Shape: (8, 10), Label: o
# Sequence Shape: (9, 10), Label: p
# Sequence Shape: (8, 10), Label: q
# Sequence Shape: (7, 10), Label: r
# Sequence Shape: (7, 10), Label: s
# Sequence Shape: (9, 10), Label: t
# Sequence Shape: (8, 10), Label: u
# Sequence Shape: (8, 10), Label: v
# Sequence Shape: (9, 10), Label: w
# Sequence Shape: (9, 10), Label: x
# Sequence Shape: (8, 10), Label: y
# Sequence Shape: (22, 10), Label: z
# Sequence Shape: (9, 10), Label: 0
# Sequence Shape: (11, 10), Label: 1
# Sequence Shape: (15, 10), Label: 2
# Sequence Shape: (10, 10), Label: 3
# Sequence Shape: (11, 10), Label: 4
# Sequence Shape: (13, 10), Label: 5
# Sequence Shape: (9, 10), Label: 6
# Sequence Shape: (11, 10), Label: 7
# Sequence Shape: (9, 10), Label: 8
# Sequence Shape: (14, 10), Label: 9
# Sequence Shape: (16, 10), Label: A
# Sequence Shape: (13, 10), Label: B
# Sequence Shape: (7, 10), Label: C
# Sequence Shape: (9, 10), Label: D
# Sequence Shape: (15, 10), Label: E
# Sequence Shape: (18, 10), Label: F
# Sequence Shape: (12, 10), Label: G
# Sequence Shape: (12, 10), Label: H
# Sequence Shape: (12, 10), Label: I
# Sequence Shape: (9, 10), Label: J
# Sequence Shape: (10, 10), Label: K
# Sequence Shape: (8, 10), Label: L
# Sequence Shape: (10, 10), Label: M
# Sequence Shape: (11, 10), Label: N
# Sequence Shape: (8, 10), Label: O
# Sequence Shape: (11, 10), Label: P
# Sequence Shape: (19, 10), Label: Q
# Sequence Shape: (10, 10), Label: R
# Sequence Shape: (9, 10), Label: S
# Sequence Shape: (9, 10), Label: T
# Sequence Shape: (10, 10), Label: U
# Sequence Shape: (9, 10), Label: V
# Sequence Shape: (14, 10), Label: W
# Sequence Shape: (10, 10), Label: X
# Sequence Shape: (13, 10), Label: Y
# Sequence Shape: (10, 10), Label: Z
# Sequence Shape: (12, 10), Label: a
# Sequence Shape: (9, 10), Label: b
# Sequence Shape: (17, 10), Label: c
# Sequence Shape: (9, 10), Label: d
# Sequence Shape: (9, 10), Label: e
# Sequence Shape: (9, 10), Label: f
# Sequence Shape: (10, 10), Label: g
# Sequence Shape: (8, 10), Label: h
# Sequence Shape: (9, 10), Label: i
# Sequence Shape: (10, 10), Label: j
# Sequence Shape: (11, 10), Label: k
# Sequence Shape: (7, 10), Label: l
# Sequence Shape: (10, 10), Label: m
# Sequence Shape: (9, 10), Label: n
# Sequence Shape: (7, 10), Label: o
# Sequence Shape: (9, 10), Label: p
# Sequence Shape: (9, 10), Label: q
# Sequence Shape: (11, 10), Label: r
# Sequence Shape: (9, 10), Label: s
# Sequence Shape: (11, 10), Label: t
# Sequence Shape: (24, 10), Label: u
# Sequence Shape: (15, 10), Label: v
# Sequence Shape: (15, 10), Label: w
# Sequence Shape: (10, 10), Label: x
# Sequence Shape: (8, 10), Label: y
# Sequence Shape: (11, 10), Label: z
# Sequence Shape: (21, 10), Label: 0
# Sequence Shape: (11, 10), Label: 1
# Sequence Shape: (9, 10), Label: 2
# Sequence Shape: (9, 10), Label: 3
# Sequence Shape: (10, 10), Label: 4
# Sequence Shape: (21, 10), Label: 5
# Sequence Shape: (11, 10), Label: 6
# Sequence Shape: (18, 10), Label: 7
# Sequence Shape: (11, 10), Label: 8
# Sequence Shape: (10, 10), Label: 9
# Sequence Shape: (12, 10), Label: A
# Sequence Shape: (11, 10), Label: B
# Sequence Shape: (10, 10), Label: C
# Sequence Shape: (10, 10), Label: D
# Sequence Shape: (13, 10), Label: E
# Sequence Shape: (12, 10), Label: F
# Sequence Shape: (10, 10), Label: G
# Sequence Shape: (11, 10), Label: H
# Sequence Shape: (11, 10), Label: I
# Sequence Shape: (17, 10), Label: J
# Sequence Shape: (12, 10), Label: K
# Sequence Shape: (9, 10), Label: L
# Sequence Shape: (11, 10), Label: M
# Sequence Shape: (11, 10), Label: N
# Sequence Shape: (37, 10), Label: O
# Sequence Shape: (20, 10), Label: P
# Sequence Shape: (10, 10), Label: Q
# Sequence Shape: (10, 10), Label: R
# Sequence Shape: (8, 10), Label: S
# Sequence Shape: (10, 10), Label: T
# Sequence Shape: (9, 10), Label: U
# Sequence Shape: (8, 10), Label: V
# Sequence Shape: (10, 10), Label: W
# Sequence Shape: (11, 10), Label: X
# Sequence Shape: (9, 10), Label: Y
# Sequence Shape: (10, 10), Label: Z
# Sequence Shape: (9, 10), Label: a
# Sequence Shape: (8, 10), Label: b
# Sequence Shape: (8, 10), Label: c
# Sequence Shape: (7, 10), Label: d
# Sequence Shape: (6, 10), Label: e
# Sequence Shape: (8, 10), Label: f
# Sequence Shape: (8, 10), Label: g
# Sequence Shape: (9, 10), Label: h
# Sequence Shape: (8, 10), Label: i
# Sequence Shape: (8, 10), Label: j
# Sequence Shape: (10, 10), Label: k
# Sequence Shape: (9, 10), Label: l
# Sequence Shape: (8, 10), Label: m
# Sequence Shape: (15, 10), Label: n
# Sequence Shape: (13, 10), Label: o
# Sequence Shape: (23, 10), Label: p
# Sequence Shape: (9, 10), Label: q
# Sequence Shape: (8, 10), Label: r
# Sequence Shape: (8, 10), Label: s
# Sequence Shape: (11, 10), Label: t
# Sequence Shape: (10, 10), Label: u
# Sequence Shape: (9, 10), Label: v
# Sequence Shape: (10, 10), Label: w
# Sequence Shape: (10, 10), Label: x
# Sequence Shape: (10, 10), Label: y
# Sequence Shape: (10, 10), Label: z
# Sequence Shape: (9, 10), Label: 0
# Sequence Shape: (11, 10), Label: 1
# Sequence Shape: (10, 10), Label: 2
# Sequence Shape: (9, 10), Label: 3
# Sequence Shape: (10, 10), Label: 4
# Sequence Shape: (18, 10), Label: 5
# Sequence Shape: (12, 10), Label: 6
# Sequence Shape: (11, 10), Label: 7
# Sequence Shape: (9, 10), Label: 8
# Sequence Shape: (10, 10), Label: 9
# Sequence Shape: (14, 10), Label: A
# Sequence Shape: (11, 10), Label: B
# Sequence Shape: (8, 10), Label: C
# Sequence Shape: (10, 10), Label: D
# Sequence Shape: (24, 10), Label: E
# Sequence Shape: (32, 10), Label: F
# Sequence Shape: (17, 10), Label: G
# Sequence Shape: (11, 10), Label: H
# Sequence Shape: (12, 10), Label: I
# Sequence Shape: (11, 10), Label: J
# Sequence Shape: (11, 10), Label: K
# Sequence Shape: (8, 10), Label: L
# Sequence Shape: (13, 10), Label: M
# Sequence Shape: (12, 10), Label: N
# Sequence Shape: (9, 10), Label: O
# Sequence Shape: (12, 10), Label: P
# Sequence Shape: (10, 10), Label: Q
# Sequence Shape: (11, 10), Label: R
# Sequence Shape: (9, 10), Label: S
# Sequence Shape: (30, 10), Label: T
# Sequence Shape: (11, 10), Label: U
# Sequence Shape: (14, 10), Label: V
# Sequence Shape: (16, 10), Label: W
# Sequence Shape: (11, 10), Label: X
# Sequence Shape: (12, 10), Label: Y
# Sequence Shape: (16, 10), Label: Z
# Sequence Shape: (17, 10), Label: a
# Sequence Shape: (9, 10), Label: b
# Sequence Shape: (7, 10), Label: c
# Sequence Shape: (9, 10), Label: d
# Sequence Shape: (11, 10), Label: e
# Sequence Shape: (10, 10), Label: f
# Sequence Shape: (9, 10), Label: g
# Sequence Shape: (9, 10), Label: h
# Sequence Shape: (10, 10), Label: i
# Sequence Shape: (10, 10), Label: j
# Sequence Shape: (9, 10), Label: k
# Sequence Shape: (13, 10), Label: l
# Sequence Shape: (10, 10), Label: m
# Sequence Shape: (9, 10), Label: n
# Sequence Shape: (14, 10), Label: o
# Sequence Shape: (11, 10), Label: p
# Sequence Shape: (12, 10), Label: q
# Sequence Shape: (10, 10), Label: r
# Sequence Shape: (10, 10), Label: s
# Sequence Shape: (11, 10), Label: t
# Sequence Shape: (9, 10), Label: u
# Sequence Shape: (10, 10), Label: v
# Sequence Shape: (14, 10), Label: w
# Sequence Shape: (25, 10), Label: x
# Sequence Shape: (11, 10), Label: y
# Sequence Shape: (14, 10), Label: z
# Sequence Shape: (23, 10), Label: 0
# Sequence Shape: (12, 10), Label: 1
# Sequence Shape: (11, 10), Label: 2
# Sequence Shape: (17, 10), Label: 3
# Sequence Shape: (6, 10), Label: 4
# Sequence Shape: (16, 10), Label: 5
# Sequence Shape: (26, 10), Label: 6
# Sequence Shape: (14, 10), Label: 7
# Sequence Shape: (12, 10), Label: 8
# Sequence Shape: (16, 10), Label: 9
# Sequence Shape: (22, 10), Label: A
# Sequence Shape: (12, 10), Label: B
# Sequence Shape: (9, 10), Label: C
# Sequence Shape: (13, 10), Label: D
# Sequence Shape: (16, 10), Label: E
# Sequence Shape: (13, 10), Label: F
# Sequence Shape: (12, 10), Label: G
# Sequence Shape: (13, 10), Label: H
# Sequence Shape: (12, 10), Label: I
# Sequence Shape: (10, 10), Label: J
# Sequence Shape: (11, 10), Label: K
# Sequence Shape: (8, 10), Label: L
# Sequence Shape: (11, 10), Label: M
# Sequence Shape: (12, 10), Label: N
# Sequence Shape: (9, 10), Label: O
# Sequence Shape: (11, 10), Label: P
# Sequence Shape: (25, 10), Label: Q
# Sequence Shape: (11, 10), Label: R
# Sequence Shape: (9, 10), Label: S
# Sequence Shape: (11, 10), Label: T
# Sequence Shape: (10, 10), Label: U
# Sequence Shape: (9, 10), Label: V
# Sequence Shape: (12, 10), Label: W
# Sequence Shape: (11, 10), Label: X
# Sequence Shape: (10, 10), Label: Y
# Sequence Shape: (10, 10), Label: Z
# Sequence Shape: (10, 10), Label: a
# Sequence Shape: (8, 10), Label: b
# Sequence Shape: (7, 10), Label: c
# Sequence Shape: (10, 10), Label: d
# Sequence Shape: (9, 10), Label: e
# Sequence Shape: (12, 10), Label: f
# Sequence Shape: (9, 10), Label: g
# Sequence Shape: (8, 10), Label: h
# Sequence Shape: (9, 10), Label: i
# Sequence Shape: (10, 10), Label: j
# Sequence Shape: (9, 10), Label: k
# Sequence Shape: (9, 10), Label: l
# Sequence Shape: (11, 10), Label: m
# Sequence Shape: (12, 10), Label: n
# Sequence Shape: (9, 10), Label: o
# Sequence Shape: (11, 10), Label: p
# Sequence Shape: (8, 10), Label: q
# Sequence Shape: (13, 10), Label: r
# Sequence Shape: (17, 10), Label: s
# Sequence Shape: (12, 10), Label: t
# Sequence Shape: (10, 10), Label: u
# Sequence Shape: (17, 10), Label: v
# Sequence Shape: (12, 10), Label: w
# Sequence Shape: (9, 10), Label: x
# Sequence Shape: (10, 10), Label: y
# Sequence Shape: (10, 10), Label: z
# Sequence Shape: (10, 10), Label: 0
# Sequence Shape: (11, 10), Label: 1
# Sequence Shape: (9, 10), Label: 2
# Sequence Shape: (10, 10), Label: 3
# Sequence Shape: (11, 10), Label: 4
# Sequence Shape: (11, 10), Label: 5
# Sequence Shape: (8, 10), Label: 6
# Sequence Shape: (15, 10), Label: 7
# Sequence Shape: (10, 10), Label: 8
# Sequence Shape: (10, 10), Label: 9
# Sequence Shape: (15, 10), Label: A
# Sequence Shape: (13, 10), Label: B
# Sequence Shape: (36, 10), Label: C
# Sequence Shape: (17, 10), Label: D
# Sequence Shape: (21, 10), Label: E
# Sequence Shape: (11, 10), Label: F
# Sequence Shape: (11, 10), Label: G
# Sequence Shape: (15, 10), Label: H
# Sequence Shape: (13, 10), Label: I
# Sequence Shape: (11, 10), Label: J
# Sequence Shape: (12, 10), Label: K
# Sequence Shape: (9, 10), Label: L
# Sequence Shape: (20, 10), Label: M
# Sequence Shape: (18, 10), Label: N
# Sequence Shape: (9, 10), Label: O
# Sequence Shape: (11, 10), Label: P
# Sequence Shape: (12, 10), Label: Q
# Sequence Shape: (12, 10), Label: R
# Sequence Shape: (9, 10), Label: S
# Sequence Shape: (11, 10), Label: T
# Sequence Shape: (10, 10), Label: U
# Sequence Shape: (9, 10), Label: V
# Sequence Shape: (11, 10), Label: W
# Sequence Shape: (10, 10), Label: X
# Sequence Shape: (10, 10), Label: Y
# Sequence Shape: (10, 10), Label: Z
# Sequence Shape: (14, 10), Label: a
# Sequence Shape: (9, 10), Label: b
# Sequence Shape: (11, 10), Label: c
# Sequence Shape: (9, 10), Label: d
# Sequence Shape: (9, 10), Label: e
# Sequence Shape: (10, 10), Label: f
# Sequence Shape: (11, 10), Label: g
# Sequence Shape: (10, 10), Label: h
# Sequence Shape: (12, 10), Label: i
# Sequence Shape: (16, 10), Label: j
# Sequence Shape: (16, 10), Label: k
# Sequence Shape: (9, 10), Label: l
# Sequence Shape: (11, 10), Label: m
# Sequence Shape: (10, 10), Label: n
# Sequence Shape: (10, 10), Label: o
# Sequence Shape: (10, 10), Label: p
# Sequence Shape: (11, 10), Label: q
# Sequence Shape: (10, 10), Label: r
# Sequence Shape: (9, 10), Label: s
# Sequence Shape: (9, 10), Label: t
# Sequence Shape: (9, 10), Label: u
# Sequence Shape: (10, 10), Label: v
# Sequence Shape: (11, 10), Label: w
# Sequence Shape: (14, 10), Label: x
# Sequence Shape: (14, 10), Label: y
# Sequence Shape: (18, 10), Label: z
# Sequence Shape: (20, 10), Label: 0
# Sequence Shape: (16, 10), Label: 1
# Sequence Shape: (10, 10), Label: 2
# Sequence Shape: (10, 10), Label: 3
# Sequence Shape: (14, 10), Label: 4
# Sequence Shape: (12, 10), Label: 5
# Sequence Shape: (10, 10), Label: 6
# Sequence Shape: (16, 10), Label: 7
# Sequence Shape: (10, 10), Label: 8
# Sequence Shape: (17, 10), Label: 9
# Sequence Shape: (14, 10), Label: A
# Sequence Shape: (12, 10), Label: B
# Sequence Shape: (9, 10), Label: C
# Sequence Shape: (11, 10), Label: D
# Sequence Shape: (15, 10), Label: E
# Sequence Shape: (11, 10), Label: F
# Sequence Shape: (10, 10), Label: G
# Sequence Shape: (13, 10), Label: H
# Sequence Shape: (12, 10), Label: I
# Sequence Shape: (12, 10), Label: J
# Sequence Shape: (12, 10), Label: K
# Sequence Shape: (10, 10), Label: L
# Sequence Shape: (19, 10), Label: M
# Sequence Shape: (12, 10), Label: N
# Sequence Shape: (11, 10), Label: O
# Sequence Shape: (13, 10), Label: P
# Sequence Shape: (17, 10), Label: Q
# Sequence Shape: (16, 10), Label: R
# Sequence Shape: (12, 10), Label: S
# Sequence Shape: (12, 10), Label: T
# Sequence Shape: (11, 10), Label: U
# Sequence Shape: (11, 10), Label: V
# Sequence Shape: (13, 10), Label: W
# Sequence Shape: (12, 10), Label: X
# Sequence Shape: (12, 10), Label: Y
# Sequence Shape: (11, 10), Label: Z
# Sequence Shape: (23, 10), Label: a
# Sequence Shape: (10, 10), Label: b
# Sequence Shape: (9, 10), Label: c
# Sequence Shape: (8, 10), Label: d
# Sequence Shape: (9, 10), Label: e
# Sequence Shape: (10, 10), Label: f
# Sequence Shape: (10, 10), Label: g
# Sequence Shape: (9, 10), Label: h
# Sequence Shape: (14, 10), Label: i
# Sequence Shape: (11, 10), Label: j
# Sequence Shape: (11, 10), Label: k
# Sequence Shape: (9, 10), Label: l
# Sequence Shape: (12, 10), Label: m
# Sequence Shape: (11, 10), Label: n
# Sequence Shape: (18, 10), Label: o
# Sequence Shape: (11, 10), Label: p
# Sequence Shape: (24, 10), Label: q
# Sequence Shape: (13, 10), Label: r
# Sequence Shape: (14, 10), Label: s
# Sequence Shape: (18, 10), Label: t
# Sequence Shape: (9, 10), Label: u
# Sequence Shape: (9, 10), Label: v
# Sequence Shape: (10, 10), Label: w
# Sequence Shape: (10, 10), Label: x
# Sequence Shape: (15, 10), Label: y
# Sequence Shape: (11, 10), Label: z
# Sequence Shape: (18, 10), Label: 0
# Sequence Shape: (11, 10), Label: 1
# Sequence Shape: (9, 10), Label: 2
# Sequence Shape: (9, 10), Label: 3
# Sequence Shape: (11, 10), Label: 4
# Sequence Shape: (13, 10), Label: 5
# Sequence Shape: (10, 10), Label: 6
# Sequence Shape: (11, 10), Label: 7
# Sequence Shape: (10, 10), Label: 8
# Sequence Shape: (10, 10), Label: 9
# Sequence Shape: (18, 10), Label: A
# Sequence Shape: (13, 10), Label: B
# Sequence Shape: (9, 10), Label: C
# Sequence Shape: (11, 10), Label: D
# Sequence Shape: (17, 10), Label: E
# Sequence Shape: (13, 10), Label: F
# Sequence Shape: (12, 10), Label: G
# Sequence Shape: (12, 10), Label: H
# Sequence Shape: (12, 10), Label: I
# Sequence Shape: (10, 10), Label: J
# Sequence Shape: (12, 10), Label: K
# Sequence Shape: (7, 10), Label: L
# Sequence Shape: (11, 10), Label: M
# Sequence Shape: (13, 10), Label: N
# Sequence Shape: (8, 10), Label: O
# Sequence Shape: (11, 10), Label: P
# Sequence Shape: (11, 10), Label: Q
# Sequence Shape: (12, 10), Label: R
# Sequence Shape: (10, 10), Label: S
# Sequence Shape: (11, 10), Label: T
# Sequence Shape: (18, 10), Label: U
# Sequence Shape: (9, 10), Label: V
# Sequence Shape: (11, 10), Label: W
# Sequence Shape: (11, 10), Label: X
# Sequence Shape: (10, 10), Label: Y
# Sequence Shape: (10, 10), Label: Z
# Sequence Shape: (10, 10), Label: a
# Sequence Shape: (9, 10), Label: b
# Sequence Shape: (7, 10), Label: c
# Sequence Shape: (14, 10), Label: d
# Sequence Shape: (10, 10), Label: e
# Sequence Shape: (10, 10), Label: f
# Sequence Shape: (9, 10), Label: g
# Sequence Shape: (9, 10), Label: h
# Sequence Shape: (9, 10), Label: i
# Sequence Shape: (9, 10), Label: j
# Sequence Shape: (10, 10), Label: k
# Sequence Shape: (8, 10), Label: l
# Sequence Shape: (10, 10), Label: m
# Sequence Shape: (9, 10), Label: n
# Sequence Shape: (10, 10), Label: o
# Sequence Shape: (11, 10), Label: p
# Sequence Shape: (10, 10), Label: q
# Sequence Shape: (13, 10), Label: r
# Sequence Shape: (9, 10), Label: s
# Sequence Shape: (11, 10), Label: t
# Sequence Shape: (10, 10), Label: u
# Sequence Shape: (9, 10), Label: v
# Sequence Shape: (12, 10), Label: w
# Sequence Shape: (10, 10), Label: x
# Sequence Shape: (10, 10), Label: y
# Sequence Shape: (12, 10), Label: z
# Sequence Shape: (9, 10), Label: 0
# Sequence Shape: (21, 10), Label: 1
# Sequence Shape: (11, 10), Label: 2
# Sequence Shape: (10, 10), Label: 3
# Sequence Shape: (12, 10), Label: 4
# Sequence Shape: (11, 10), Label: 5
# Sequence Shape: (10, 10), Label: 6
# Sequence Shape: (10, 10), Label: 7
# Sequence Shape: (18, 10), Label: 8
# Sequence Shape: (14, 10), Label: 9
# Sequence Shape: (21, 10), Label: A
# Sequence Shape: (12, 10), Label: B
# Sequence Shape: (9, 10), Label: C
# Sequence Shape: (10, 10), Label: D
# Sequence Shape: (14, 10), Label: E
# Sequence Shape: (10, 10), Label: F
# Sequence Shape: (10, 10), Label: G
# Sequence Shape: (11, 10), Label: H
# Sequence Shape: (12, 10), Label: I
# Sequence Shape: (10, 10), Label: J
# Sequence Shape: (11, 10), Label: K
# Sequence Shape: (8, 10), Label: L
# Sequence Shape: (11, 10), Label: M
# Sequence Shape: (10, 10), Label: N
# Sequence Shape: (9, 10), Label: O
# Sequence Shape: (10, 10), Label: P
# Sequence Shape: (10, 10), Label: Q
# Sequence Shape: (10, 10), Label: R
# Sequence Shape: (12, 10), Label: S
# Sequence Shape: (9, 10), Label: T
# Sequence Shape: (11, 10), Label: U
# Sequence Shape: (12, 10), Label: V
# Sequence Shape: (13, 10), Label: W
# Sequence Shape: (11, 10), Label: X
# Sequence Shape: (13, 10), Label: Y
# Sequence Shape: (14, 10), Label: Z
# Sequence Shape: (11, 10), Label: a
# Sequence Shape: (10, 10), Label: b
# Sequence Shape: (8, 10), Label: c
# Sequence Shape: (9, 10), Label: d
# Sequence Shape: (9, 10), Label: e
# Sequence Shape: (11, 10), Label: f
# Sequence Shape: (14, 10), Label: g
# Sequence Shape: (8, 10), Label: h
# Sequence Shape: (9, 10), Label: i
# Sequence Shape: (9, 10), Label: j
# Sequence Shape: (10, 10), Label: k
# Sequence Shape: (7, 10), Label: l
# Sequence Shape: (10, 10), Label: m
# Sequence Shape: (9, 10), Label: n
# Sequence Shape: (8, 10), Label: o
# Sequence Shape: (10, 10), Label: p
# Sequence Shape: (10, 10), Label: q
# Sequence Shape: (8, 10), Label: r
# Sequence Shape: (8, 10), Label: s
# Sequence Shape: (9, 10), Label: t
# Sequence Shape: (10, 10), Label: u
# Sequence Shape: (9, 10), Label: v
# Sequence Shape: (13, 10), Label: w
# Sequence Shape: (25, 10), Label: x
# Sequence Shape: (11, 10), Label: y
# Sequence Shape: (12, 10), Label: z
# Sequence Shape: (16, 10), Label: 0
# Sequence Shape: (13, 10), Label: 1
# Sequence Shape: (13, 10), Label: 2
# Sequence Shape: (10, 10), Label: 3
# Sequence Shape: (15, 10), Label: 4
# Sequence Shape: (13, 10), Label: 5
# Sequence Shape: (11, 10), Label: 6
# Sequence Shape: (11, 10), Label: 7
# Sequence Shape: (13, 10), Label: 8
# Sequence Shape: (14, 10), Label: 9
# Sequence Shape: (13, 10), Label: A
# Sequence Shape: (11, 10), Label: B
# Sequence Shape: (9, 10), Label: C
# Sequence Shape: (13, 10), Label: D
# Sequence Shape: (15, 10), Label: E
# Sequence Shape: (13, 10), Label: F
# Sequence Shape: (11, 10), Label: G
# Sequence Shape: (12, 10), Label: H
# Sequence Shape: (10, 10), Label: I
# Sequence Shape: (10, 10), Label: J
# Sequence Shape: (9, 10), Label: K
# Sequence Shape: (7, 10), Label: L
# Sequence Shape: (10, 10), Label: M
# Sequence Shape: (11, 10), Label: N
# Sequence Shape: (9, 10), Label: O
# Sequence Shape: (10, 10), Label: P
# Sequence Shape: (12, 10), Label: Q
# Sequence Shape: (11, 10), Label: R
# Sequence Shape: (9, 10), Label: S
# Sequence Shape: (12, 10), Label: T
# Sequence Shape: (9, 10), Label: U
# Sequence Shape: (9, 10), Label: V
# Sequence Shape: (11, 10), Label: W
# Sequence Shape: (11, 10), Label: X
# Sequence Shape: (12, 10), Label: Y
# Sequence Shape: (10, 10), Label: Z
# Sequence Shape: (18, 10), Label: a
# Sequence Shape: (9, 10), Label: b
# Sequence Shape: (15, 10), Label: c
# Sequence Shape: (9, 10), Label: d
# Sequence Shape: (10, 10), Label: e
# Sequence Shape: (10, 10), Label: f
# Sequence Shape: (9, 10), Label: g
# Sequence Shape: (9, 10), Label: h
# Sequence Shape: (9, 10), Label: i
# Sequence Shape: (14, 10), Label: j
# Sequence Shape: (5, 10), Label: k
# Sequence Shape: (8, 10), Label: l
# Sequence Shape: (10, 10), Label: m
# Sequence Shape: (9, 10), Label: n
# Sequence Shape: (10, 10), Label: o
# Sequence Shape: (11, 10), Label: p
# Sequence Shape: (11, 10), Label: q
# Sequence Shape: (9, 10), Label: r
# Sequence Shape: (9, 10), Label: s
# Sequence Shape: (12, 10), Label: t
# Sequence Shape: (9, 10), Label: u
# Sequence Shape: (27, 10), Label: v
# Sequence Shape: (17, 10), Label: w
# Sequence Shape: (20, 10), Label: x
# Sequence Shape: (10, 10), Label: y
# Sequence Shape: (17, 10), Label: z
# Sequence Shape: (19, 10), Label: 0
# Sequence Shape: (12, 10), Label: 1
# Sequence Shape: (9, 10), Label: 2
# Sequence Shape: (10, 10), Label: 3
# Sequence Shape: (12, 10), Label: 4
# Sequence Shape: (11, 10), Label: 5
# Sequence Shape: (9, 10), Label: 6
# Sequence Shape: (11, 10), Label: 7
# Sequence Shape: (9, 10), Label: 8
# Sequence Shape: (10, 10), Label: 9
# Sequence Shape: (21, 10), Label: A
# Sequence Shape: (12, 10), Label: B
# Sequence Shape: (9, 10), Label: C
# Sequence Shape: (11, 10), Label: D
# Sequence Shape: (20, 10), Label: E
# Sequence Shape: (13, 10), Label: F
# Sequence Shape: (13, 10), Label: G
# Sequence Shape: (12, 10), Label: H
# Sequence Shape: (10, 10), Label: I
# Sequence Shape: (9, 10), Label: J
# Sequence Shape: (10, 10), Label: K
# Sequence Shape: (7, 10), Label: L
# Sequence Shape: (10, 10), Label: M
# Sequence Shape: (12, 10), Label: N
# Sequence Shape: (9, 10), Label: O
# Sequence Shape: (10, 10), Label: P
# Sequence Shape: (10, 10), Label: Q
# Sequence Shape: (12, 10), Label: R
# Sequence Shape: (9, 10), Label: S
# Sequence Shape: (10, 10), Label: T
# Sequence Shape: (10, 10), Label: U
# Sequence Shape: (10, 10), Label: V
# Sequence Shape: (11, 10), Label: W
# Sequence Shape: (11, 10), Label: X
# Sequence Shape: (10, 10), Label: Y
# Sequence Shape: (11, 10), Label: Z
# Sequence Shape: (9, 10), Label: a
# Sequence Shape: (10, 10), Label: b
# Sequence Shape: (7, 10), Label: c
# Sequence Shape: (10, 10), Label: d
# Sequence Shape: (10, 10), Label: e
# Sequence Shape: (10, 10), Label: f
# Sequence Shape: (9, 10), Label: g
# Sequence Shape: (22, 10), Label: h
# Sequence Shape: (17, 10), Label: i
# Sequence Shape: (10, 10), Label: j
# Sequence Shape: (17, 10), Label: k
# Sequence Shape: (8, 10), Label: l
# Sequence Shape: (11, 10), Label: m
# Sequence Shape: (8, 10), Label: n
# Sequence Shape: (10, 10), Label: o
# Sequence Shape: (10, 10), Label: p
# Sequence Shape: (10, 10), Label: q
# Sequence Shape: (9, 10), Label: r
# Sequence Shape: (8, 10), Label: s
# Sequence Shape: (10, 10), Label: t
# Sequence Shape: (10, 10), Label: u
# Sequence Shape: (15, 10), Label: v
# Sequence Shape: (12, 10), Label: w
# Sequence Shape: (15, 10), Label: x
# Sequence Shape: (17, 10), Label: y
# Sequence Shape: (20, 10), Label: z
# Sequence Shape: (16, 10), Label: 0
# Sequence Shape: (26, 10), Label: 1
# Sequence Shape: (21, 10), Label: 2
# Sequence Shape: (19, 10), Label: 3
# Sequence Shape: (17, 10), Label: 4
# Sequence Shape: (11, 10), Label: 5
# Sequence Shape: (9, 10), Label: 6
# Sequence Shape: (10, 10), Label: 7
# Sequence Shape: (10, 10), Label: 8
# Sequence Shape: (10, 10), Label: 9
# Sequence Shape: (21, 10), Label: A
# Sequence Shape: (11, 10), Label: B
# Sequence Shape: (8, 10), Label: C
# Sequence Shape: (10, 10), Label: D
# Sequence Shape: (13, 10), Label: E
# Sequence Shape: (10, 10), Label: F
# Sequence Shape: (14, 10), Label: G
# Sequence Shape: (10, 10), Label: H
# Sequence Shape: (11, 10), Label: I
# Sequence Shape: (9, 10), Label: J
# Sequence Shape: (9, 10), Label: K
# Sequence Shape: (8, 10), Label: L
# Sequence Shape: (11, 10), Label: M
# Sequence Shape: (10, 10), Label: N
# Sequence Shape: (8, 10), Label: O
# Sequence Shape: (10, 10), Label: P
# Sequence Shape: (10, 10), Label: Q
# Sequence Shape: (9, 10), Label: R
# Sequence Shape: (8, 10), Label: S
# Sequence Shape: (11, 10), Label: T
# ...
# Sequence Shape: (7, 10), Label: e
# Sequence Shape: (7, 10), Label: f
# Sequence Shape: (8, 10), Label: g
# Sequence Shape: (10, 10), Label: h
# Sequence Shape: (11, 10), Label: i
# Sequence Shape: (8, 10), Label: j
# Sequence Shape: (9, 10), Label: k
# Sequence Shape: (7, 10), Label: l
# Sequence Shape: (8, 10), Label: m
# Sequence Shape: (7, 10), Label: n
# Sequence Shape: (7, 10), Label: o
# Sequence Shape: (8, 10), Label: p
# Sequence Shape: (8, 10), Label: q
# Sequence Shape: (6, 10), Label: r
# Sequence Shape: (7, 10), Label: s
# Sequence Shape: (10, 10), Label: t
# Sequence Shape: (8, 10), Label: u
# Sequence Shape: (17, 10), Label: v
# Sequence Shape: (10, 10), Label: w
# Sequence Shape: (17, 10), Label: x
# Sequence Shape: (6, 10), Label: y
# Sequence Shape: (21, 10), Label: z
# Sequence Shape: (9, 10), Label: 0
# Sequence Shape: (10, 10), Label: 1
# Sequence Shape: (9, 10), Label: 2
# Sequence Shape: (7, 10), Label: 3
# Sequence Shape: (11, 10), Label: 4
# Sequence Shape: (12, 10), Label: 5
# Sequence Shape: (8, 10), Label: 6
# Sequence Shape: (15, 10), Label: 7
# Sequence Shape: (9, 10), Label: 8
# Sequence Shape: (11, 10), Label: 9
# Sequence Shape: (12, 10), Label: A
# Sequence Shape: (9, 10), Label: B
# Sequence Shape: (13, 10), Label: C
# Sequence Shape: (10, 10), Label: D
# Sequence Shape: (11, 10), Label: E
# Sequence Shape: (11, 10), Label: F
# Sequence Shape: (10, 10), Label: G
# Sequence Shape: (10, 10), Label: H
# Sequence Shape: (11, 10), Label: I
# Sequence Shape: (10, 10), Label: J
# Sequence Shape: (8, 10), Label: K
# Sequence Shape: (6, 10), Label: L
# Sequence Shape: (10, 10), Label: M
# Sequence Shape: (9, 10), Label: N
# Sequence Shape: (7, 10), Label: O
# Sequence Shape: (8, 10), Label: P
# Sequence Shape: (10, 10), Label: Q
# Sequence Shape: (9, 10), Label: R
# Sequence Shape: (7, 10), Label: S
# Sequence Shape: (14, 10), Label: T
# Sequence Shape: (8, 10), Label: U
# Sequence Shape: (10, 10), Label: V
# Sequence Shape: (9, 10), Label: W
# Sequence Shape: (8, 10), Label: X
# Sequence Shape: (14, 10), Label: Y
# Sequence Shape: (9, 10), Label: Z
# Sequence Shape: (8, 10), Label: a
# Sequence Shape: (7, 10), Label: b
# Sequence Shape: (7, 10), Label: c
# Sequence Shape: (8, 10), Label: d
# Sequence Shape: (7, 10), Label: e
# Sequence Shape: (8, 10), Label: f
# Sequence Shape: (7, 10), Label: g
# Sequence Shape: (7, 10), Label: h
# Sequence Shape: (8, 10), Label: i
# Sequence Shape: (10, 10), Label: j
# Sequence Shape: (15, 10), Label: k
# Sequence Shape: (8, 10), Label: l
# Sequence Shape: (10, 10), Label: m
# Sequence Shape: (7, 10), Label: n
# Sequence Shape: (8, 10), Label: o
# Sequence Shape: (12, 10), Label: p
# Sequence Shape: (7, 10), Label: q
# Sequence Shape: (14, 10), Label: r
# Sequence Shape: (15, 10), Label: s
# Sequence Shape: (16, 10), Label: t
# Sequence Shape: (16, 10), Label: u
# Sequence Shape: (7, 10), Label: v
# Sequence Shape: (9, 10), Label: w
# Sequence Shape: (8, 10), Label: x
# Sequence Shape: (10, 10), Label: y
# Sequence Shape: (10, 10), Label: z
# Sequence Shape: (14, 10), Label: 0
# Sequence Shape: (12, 10), Label: 1
# Sequence Shape: (8, 10), Label: 2
# Sequence Shape: (8, 10), Label: 3
# Sequence Shape: (10, 10), Label: 4
# Sequence Shape: (10, 10), Label: 5
# Sequence Shape: (10, 10), Label: 6
# Sequence Shape: (8, 10), Label: 7
# Sequence Shape: (7, 10), Label: 8
# Sequence Shape: (13, 10), Label: 9
# Sequence Shape: (13, 10), Label: A
# Sequence Shape: (10, 10), Label: B
# Sequence Shape: (9, 10), Label: C
# Sequence Shape: (9, 10), Label: D
# Sequence Shape: (12, 10), Label: E
# Sequence Shape: (11, 10), Label: F
# Sequence Shape: (11, 10), Label: G
# Sequence Shape: (11, 10), Label: H
# Sequence Shape: (10, 10), Label: I
# Sequence Shape: (9, 10), Label: J
# Sequence Shape: (14, 10), Label: K
# Sequence Shape: (15, 10), Label: L
# Sequence Shape: (9, 10), Label: M
# Sequence Shape: (11, 10), Label: N
# Sequence Shape: (12, 10), Label: O
# Sequence Shape: (8, 10), Label: P
# Sequence Shape: (10, 10), Label: Q
# Sequence Shape: (9, 10), Label: R
# Sequence Shape: (8, 10), Label: S
# Sequence Shape: (10, 10), Label: T
# Sequence Shape: (8, 10), Label: U
# Sequence Shape: (7, 10), Label: V
# Sequence Shape: (8, 10), Label: W
# Sequence Shape: (7, 10), Label: X
# Sequence Shape: (9, 10), Label: Y
# Sequence Shape: (9, 10), Label: Z
# Sequence Shape: (9, 10), Label: a
# Sequence Shape: (7, 10), Label: b
# Sequence Shape: (6, 10), Label: c
# Sequence Shape: (7, 10), Label: d
# Sequence Shape: (7, 10), Label: e
# Sequence Shape: (7, 10), Label: f
# Sequence Shape: (7, 10), Label: g
# Sequence Shape: (6, 10), Label: h
# Sequence Shape: (6, 10), Label: i
# Sequence Shape: (6, 10), Label: j
# Sequence Shape: (8, 10), Label: k
# Sequence Shape: (13, 10), Label: l
# Sequence Shape: (10, 10), Label: m
# Sequence Shape: (8, 10), Label: n
# Sequence Shape: (7, 10), Label: o
# Sequence Shape: (9, 10), Label: p
# Sequence Shape: (9, 10), Label: q
# Sequence Shape: (7, 10), Label: r
# Sequence Shape: (7, 10), Label: s
# Sequence Shape: (7, 10), Label: t
# Sequence Shape: (18, 10), Label: u
# Sequence Shape: (8, 10), Label: v
# Sequence Shape: (15, 10), Label: w
# Sequence Shape: (9, 10), Label: x
# Sequence Shape: (9, 10), Label: y
# Sequence Shape: (15, 10), Label: z
# Sequence Shape: (17, 10), Label: 0
# Sequence Shape: (11, 10), Label: 1
# Sequence Shape: (8, 10), Label: 2
# Sequence Shape: (8, 10), Label: 3
# Sequence Shape: (10, 10), Label: 4
# Sequence Shape: (9, 10), Label: 5
# Sequence Shape: (7, 10), Label: 6
# Sequence Shape: (9, 10), Label: 7
# Sequence Shape: (9, 10), Label: 8
# Sequence Shape: (9, 10), Label: 9
# Sequence Shape: (11, 10), Label: A
# Sequence Shape: (9, 10), Label: B
# Sequence Shape: (7, 10), Label: C
# Sequence Shape: (9, 10), Label: D
# Sequence Shape: (13, 10), Label: E
# Sequence Shape: (10, 10), Label: F
# Sequence Shape: (9, 10), Label: G
# Sequence Shape: (9, 10), Label: H
# Sequence Shape: (10, 10), Label: I
# Sequence Shape: (8, 10), Label: J
# Sequence Shape: (8, 10), Label: K
# Sequence Shape: (8, 10), Label: L
# Sequence Shape: (9, 10), Label: M
# Sequence Shape: (20, 10), Label: N
# Sequence Shape: (15, 10), Label: O
# Sequence Shape: (8, 10), Label: P
# Sequence Shape: (15, 10), Label: Q
# Sequence Shape: (10, 10), Label: R
# Sequence Shape: (7, 10), Label: S
# Sequence Shape: (8, 10), Label: T
# Sequence Shape: (8, 10), Label: U
# Sequence Shape: (9, 10), Label: V
# Sequence Shape: (10, 10), Label: W
# Sequence Shape: (9, 10), Label: X
# Sequence Shape: (11, 10), Label: Y
# Sequence Shape: (10, 10), Label: Z
# Sequence Shape: (18, 10), Label: a
# Sequence Shape: (14, 10), Label: b
# Sequence Shape: (9, 10), Label: c
# Sequence Shape: (8, 10), Label: d
# Sequence Shape: (8, 10), Label: e
# Sequence Shape: (17, 10), Label: f
# Sequence Shape: (13, 10), Label: g
# Sequence Shape: (8, 10), Label: h
# Sequence Shape: (9, 10), Label: i
# Sequence Shape: (10, 10), Label: j
# Sequence Shape: (9, 10), Label: k
# Sequence Shape: (6, 10), Label: l
# Sequence Shape: (9, 10), Label: m
# Sequence Shape: (8, 10), Label: n
# Sequence Shape: (6, 10), Label: o
# Sequence Shape: (9, 10), Label: p
# Sequence Shape: (9, 10), Label: q
# Sequence Shape: (7, 10), Label: r
# Sequence Shape: (8, 10), Label: s
# Sequence Shape: (11, 10), Label: t
# Sequence Shape: (9, 10), Label: u
# Sequence Shape: (7, 10), Label: v
# Sequence Shape: (9, 10), Label: w
# Sequence Shape: (8, 10), Label: x
# Sequence Shape: (9, 10), Label: y
# Sequence Shape: (12, 10), Label: z
# Sequence Shape: (7, 10), Label: 0
# Sequence Shape: (9, 10), Label: 1
# Sequence Shape: (7, 10), Label: 2
# Sequence Shape: (7, 10), Label: 3
# Sequence Shape: (9, 10), Label: 4
# Sequence Shape: (10, 10), Label: 5
# Sequence Shape: (7, 10), Label: 6
# Sequence Shape: (8, 10), Label: 7
# Sequence Shape: (8, 10), Label: 8
# Sequence Shape: (8, 10), Label: 9
# Sequence Shape: (12, 10), Label: A
# Sequence Shape: (9, 10), Label: B
# Sequence Shape: (7, 10), Label: C
# Sequence Shape: (9, 10), Label: D
# Sequence Shape: (12, 10), Label: E
# Sequence Shape: (9, 10), Label: F
# Sequence Shape: (8, 10), Label: G
# Sequence Shape: (9, 10), Label: H
# Sequence Shape: (9, 10), Label: I
# Sequence Shape: (8, 10), Label: J
# Sequence Shape: (9, 10), Label: K
# Sequence Shape: (7, 10), Label: L
# Sequence Shape: (8, 10), Label: M
# Sequence Shape: (8, 10), Label: N
# Sequence Shape: (8, 10), Label: O
# Sequence Shape: (9, 10), Label: P
# Sequence Shape: (8, 10), Label: Q
# Sequence Shape: (8, 10), Label: R
# Sequence Shape: (8, 10), Label: S
# Sequence Shape: (9, 10), Label: T
# Sequence Shape: (9, 10), Label: U
# Sequence Shape: (9, 10), Label: V
# Sequence Shape: (9, 10), Label: W
# Sequence Shape: (9, 10), Label: X
# Sequence Shape: (23, 10), Label: Y
# Sequence Shape: (14, 10), Label: Z
# Sequence Shape: (8, 10), Label: a
# Sequence Shape: (8, 10), Label: b
# Sequence Shape: (7, 10), Label: c
# Sequence Shape: (7, 10), Label: d
# Sequence Shape: (7, 10), Label: e
# Sequence Shape: (8, 10), Label: f
# Sequence Shape: (8, 10), Label: g
# Sequence Shape: (7, 10), Label: h
# Sequence Shape: (8, 10), Label: i
# Sequence Shape: (10, 10), Label: j
# Sequence Shape: (8, 10), Label: k
# Sequence Shape: (7, 10), Label: l
# Sequence Shape: (9, 10), Label: m
# Sequence Shape: (7, 10), Label: n
# Sequence Shape: (7, 10), Label: o
# Sequence Shape: (7, 10), Label: p
# Sequence Shape: (8, 10), Label: q
# Sequence Shape: (7, 10), Label: r
# Sequence Shape: (9, 10), Label: s
# Sequence Shape: (13, 10), Label: t
# Sequence Shape: (7, 10), Label: u
# Sequence Shape: (7, 10), Label: v
# Sequence Shape: (8, 10), Label: w
# Sequence Shape: (7, 10), Label: x
# Sequence Shape: (9, 10), Label: y
# Sequence Shape: (10, 10), Label: z
# Sequence Shape: (14, 10), Label: 0
# Sequence Shape: (9, 10), Label: 1
# Sequence Shape: (7, 10), Label: 2
# Sequence Shape: (11, 10), Label: 3
# Sequence Shape: (9, 10), Label: 4
# Sequence Shape: (9, 10), Label: 5
# Sequence Shape: (7, 10), Label: 6
# Sequence Shape: (8, 10), Label: 7
# Sequence Shape: (8, 10), Label: 8
# Sequence Shape: (10, 10), Label: 9
# Sequence Shape: (12, 10), Label: A
# Sequence Shape: (9, 10), Label: B
# Sequence Shape: (7, 10), Label: C
# Sequence Shape: (9, 10), Label: D
# Sequence Shape: (11, 10), Label: E
# Sequence Shape: (9, 10), Label: F
# Sequence Shape: (10, 10), Label: G
# Sequence Shape: (9, 10), Label: H
# Sequence Shape: (11, 10), Label: I
# Sequence Shape: (9, 10), Label: J
# Sequence Shape: (9, 10), Label: K
# Sequence Shape: (9, 10), Label: L
# Sequence Shape: (12, 10), Label: M
# Sequence Shape: (13, 10), Label: N
# Sequence Shape: (16, 10), Label: O
# Sequence Shape: (22, 10), Label: P
# Sequence Shape: (16, 10), Label: Q
# Sequence Shape: (10, 10), Label: R
# Sequence Shape: (9, 10), Label: S
# Sequence Shape: (19, 10), Label: T
# Sequence Shape: (8, 10), Label: U
# Sequence Shape: (8, 10), Label: V
# Sequence Shape: (10, 10), Label: W
# Sequence Shape: (9, 10), Label: X
# Sequence Shape: (10, 10), Label: Y
# Sequence Shape: (9, 10), Label: Z
# Sequence Shape: (8, 10), Label: a
# Sequence Shape: (7, 10), Label: b
# Sequence Shape: (7, 10), Label: c
# Sequence Shape: (8, 10), Label: d
# Sequence Shape: (8, 10), Label: e
# Sequence Shape: (8, 10), Label: f
# Sequence Shape: (8, 10), Label: g
# Sequence Shape: (8, 10), Label: h
# Sequence Shape: (8, 10), Label: i
# Sequence Shape: (7, 10), Label: j
# Sequence Shape: (8, 10), Label: k
# Sequence Shape: (6, 10), Label: l
# Sequence Shape: (10, 10), Label: m
# Sequence Shape: (8, 10), Label: n
# Sequence Shape: (8, 10), Label: o
# Sequence Shape: (8, 10), Label: p
# Sequence Shape: (8, 10), Label: q
# Sequence Shape: (7, 10), Label: r
# Sequence Shape: (8, 10), Label: s
# Sequence Shape: (8, 10), Label: t
# Sequence Shape: (8, 10), Label: u
# Sequence Shape: (8, 10), Label: v
# Sequence Shape: (8, 10), Label: w
# Sequence Shape: (8, 10), Label: x
# Sequence Shape: (14, 10), Label: y
# Sequence Shape: (5, 10), Label: z
# Sequence Shape: (12, 10), Label: 0
# Sequence Shape: (9, 10), Label: 1
# Sequence Shape: (8, 10), Label: 2
# Sequence Shape: (8, 10), Label: 3
# Sequence Shape: (8, 10), Label: 4
# Sequence Shape: (10, 10), Label: 5
# Sequence Shape: (8, 10), Label: 6
# Sequence Shape: (6, 10), Label: 7
# Sequence Shape: (9, 10), Label: 8
# Sequence Shape: (10, 10), Label: 9
# Sequence Shape: (12, 10), Label: A
# Sequence Shape: (10, 10), Label: B
# Sequence Shape: (7, 10), Label: C
# Sequence Shape: (17, 10), Label: D
# Sequence Shape: (12, 10), Label: E
# Sequence Shape: (9, 10), Label: F
# Sequence Shape: (9, 10), Label: G
# Sequence Shape: (10, 10), Label: H
# Sequence Shape: (9, 10), Label: I
# Sequence Shape: (8, 10), Label: J
# Sequence Shape: (9, 10), Label: K
# Sequence Shape: (7, 10), Label: L
# Sequence Shape: (9, 10), Label: M
# Sequence Shape: (9, 10), Label: N
# Sequence Shape: (9, 10), Label: O
# Sequence Shape: (17, 10), Label: P
# Sequence Shape: (9, 10), Label: Q
# Sequence Shape: (10, 10), Label: R
# Sequence Shape: (8, 10), Label: S
# Sequence Shape: (8, 10), Label: T
# Sequence Shape: (8, 10), Label: U
# Sequence Shape: (8, 10), Label: V
# Sequence Shape: (10, 10), Label: W
# Sequence Shape: (11, 10), Label: X
# Sequence Shape: (10, 10), Label: Y
# Sequence Shape: (9, 10), Label: Z
# Sequence Shape: (8, 10), Label: a
# Sequence Shape: (8, 10), Label: b
# Sequence Shape: (6, 10), Label: c
# Sequence Shape: (8, 10), Label: d
# Sequence Shape: (8, 10), Label: e
# Sequence Shape: (9, 10), Label: f
# Sequence Shape: (9, 10), Label: g
# Sequence Shape: (7, 10), Label: h
# Sequence Shape: (9, 10), Label: i
# Sequence Shape: (8, 10), Label: j
# Sequence Shape: (9, 10), Label: k
# Sequence Shape: (8, 10), Label: l
# Sequence Shape: (9, 10), Label: m
# Sequence Shape: (13, 10), Label: n
# Sequence Shape: (14, 10), Label: o
# Sequence Shape: (9, 10), Label: p
# Sequence Shape: (10, 10), Label: q
# Sequence Shape: (7, 10), Label: r
# Sequence Shape: (8, 10), Label: s
# Sequence Shape: (8, 10), Label: t
# Sequence Shape: (8, 10), Label: u
# Sequence Shape: (8, 10), Label: v
# Sequence Shape: (8, 10), Label: w
# Sequence Shape: (9, 10), Label: x
# Sequence Shape: (10, 10), Label: y
# Sequence Shape: (12, 10), Label: z
# Sequence Shape: (8, 10), Label: 0
# Sequence Shape: (9, 10), Label: 1
# Sequence Shape: (9, 10), Label: 2
# Sequence Shape: (9, 10), Label: 3
# Sequence Shape: (10, 10), Label: 4
# Sequence Shape: (10, 10), Label: 5
# Sequence Shape: (8, 10), Label: 6
# Sequence Shape: (9, 10), Label: 7
# Sequence Shape: (9, 10), Label: 8
# Sequence Shape: (9, 10), Label: 9
# Sequence Shape: (11, 10), Label: A
# Sequence Shape: (9, 10), Label: B
# Sequence Shape: (6, 10), Label: C
# Sequence Shape: (8, 10), Label: D
# Sequence Shape: (12, 10), Label: E
# Sequence Shape: (9, 10), Label: F
# Sequence Shape: (9, 10), Label: G
# Sequence Shape: (9, 10), Label: H
# Sequence Shape: (10, 10), Label: I
# Sequence Shape: (8, 10), Label: J
# Sequence Shape: (8, 10), Label: K
# Sequence Shape: (7, 10), Label: L
# Sequence Shape: (8, 10), Label: M
# Sequence Shape: (8, 10), Label: N
# Sequence Shape: (7, 10), Label: O
# Sequence Shape: (8, 10), Label: P
# Sequence Shape: (10, 10), Label: Q
# Sequence Shape: (11, 10), Label: R
# Sequence Shape: (9, 10), Label: S
# Sequence Shape: (9, 10), Label: T
# Sequence Shape: (9, 10), Label: U
# Sequence Shape: (8, 10), Label: V
# Sequence Shape: (9, 10), Label: W
# Sequence Shape: (9, 10), Label: X
# Sequence Shape: (9, 10), Label: Y
# Sequence Shape: (8, 10), Label: Z
# Sequence Shape: (8, 10), Label: a
# Sequence Shape: (9, 10), Label: b
# Sequence Shape: (7, 10), Label: c
# Sequence Shape: (8, 10), Label: d
# Sequence Shape: (8, 10), Label: e
# Sequence Shape: (8, 10), Label: f
# Sequence Shape: (8, 10), Label: g
# Sequence Shape: (6, 10), Label: h
# Sequence Shape: (8, 10), Label: i
# Sequence Shape: (10, 10), Label: j
# Sequence Shape: (9, 10), Label: k
# Sequence Shape: (8, 10), Label: l
# Sequence Shape: (9, 10), Label: m
# Sequence Shape: (8, 10), Label: n
# Sequence Shape: (9, 10), Label: o
# Sequence Shape: (8, 10), Label: p
# Sequence Shape: (9, 10), Label: q
# Sequence Shape: (8, 10), Label: r
# Sequence Shape: (8, 10), Label: s
# Sequence Shape: (10, 10), Label: t
# Sequence Shape: (7, 10), Label: u
# Sequence Shape: (7, 10), Label: v
# Sequence Shape: (8, 10), Label: w
# Sequence Shape: (9, 10), Label: x
# Sequence Shape: (8, 10), Label: y
# Sequence Shape: (11, 10), Label: z
# Sequence Shape: (11, 10), Label: 0
# Sequence Shape: (8, 10), Label: 1
# Sequence Shape: (9, 10), Label: 2
# Sequence Shape: (7, 10), Label: 3
# Sequence Shape: (12, 10), Label: 4
# Sequence Shape: (8, 10), Label: 5
# Sequence Shape: (7, 10), Label: 6
# Sequence Shape: (8, 10), Label: 7
# Sequence Shape: (7, 10), Label: 8
# Sequence Shape: (9, 10), Label: 9

# %%
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Create sequences and labels
sequences, labels = create_sequences(filtered_data)

# Map labels to integer indices
unique_labels = list(set(labels))
max_label_length = max([len(label) for label in unique_labels])
characters = set(char for label in unique_labels for char in label)

print("max_label_length: ", max_label_length)

# Define a blank token (typically represented as an empty string or a special character)
blank_token = '-'

# Update the StringLookup layers with the extended vocabulary
char_to_num = layers.StringLookup(
    vocabulary=list(characters), mask_token=None, oov_token=blank_token
)

num_to_char = layers.StringLookup(
    vocabulary=char_to_num.get_vocabulary(), mask_token=None, invert=True
)

# Map labels to integer indices, including the blank token where needed
labels = [char_to_num(tf.strings.unicode_split(label, input_encoding="UTF-8")) for label in labels]

# Verify the vocabulary including the blank index
print(f"Vocabulary: {char_to_num.get_vocabulary()}")
print(f"Blank token index: {char_to_num(blank_token).numpy()}")

# Pad the labels with a safe padding value, e.g., -1
padded_labels = pad_sequences(labels, maxlen=max_label_length, padding='post', value=-1)

# Convert to a TensorFlow tensor and replace -1 with the CTC blank index (0)
padded_labels = tf.where(padded_labels == -1, tf.cast(0, tf.int32), tf.convert_to_tensor(padded_labels, dtype=tf.int32))

print(f"Padded Labels Shape: {padded_labels.shape}")  # Expected: (batch_size, max_label_length)
# Out:
# max_label_length:  1
# Vocabulary: ['-', 'A', 'N', 'd', 'Y', 'I', 'x', '9', 'e', 'p', 'k', '2', 'O', 'j', 'U', 'Z', 'H', '1', '8', '0', 'D', 'C', 'q', 'n', 'B', 'K', '3', 'E', 'T', 'L', 'm', 'S', 'P', '7', 't', 'g', 'b', 'F', 'c', 'y', 'z', 'X', 'i', 'u', 'o', 'f', 'w', 's', 'a', 'G', 'V', 'Q', 'J', 'R', 'h', 'l', 'r', '5', '6', 'M', 'W', '4', 'v']
# Blank token index: 0
# Padded Labels Shape: (3094, 1)

# %%
# Define padding parameters
max_length = max([len(seq) for seq in sequences])  # Longest sequence
min_length = 0  # Minimum acceptable length for sequences

# Filter out very short sequences
filtered_sequences = [seq for seq in sequences if seq.shape[0] >= min_length]
filtered_labels = [label for seq, label in zip(sequences, padded_labels) if seq.shape[0] >= min_length]

# Pad sequences to the same length
padded_sequences = pad_sequences(filtered_sequences, maxlen=max_length, padding='post', dtype='float32', value=0)

# Verify the new shapes
print(f"Padded Sequences Shape: {padded_sequences.shape}")
print(f"Filtered Labels Count: {len(filtered_labels)}")

print("Max length: ", max_length)
# Out:
# Padded Sequences Shape: (3094, 48, 10)
# Filtered Labels Count: 3094
# Max length:  48

# %%
import tensorflow as tf
import random

def split_data(sequences, labels, train_size=0.7, shuffle=True):
    # Get dataset size
    size = tf.shape(sequences)[0].numpy()  # Get number of sequences

    # Create indices using TensorFlow's range
    indices = list(range(size))  # Using Python list to avoid TensorFlow slicing issues

    if shuffle:
        random.shuffle(indices)  # Shuffle indices in-place using Python

    # Calculate training set size
    train_samples = int(size * train_size)

    # Convert indices to TensorFlow tensors for tensor slicing
    train_idx = tf.convert_to_tensor(indices[:train_samples])
    valid_idx = tf.convert_to_tensor(indices[train_samples:])

    # Slice sequences properly using TensorFlow
    x_train = tf.gather(sequences, train_idx)
    x_valid = tf.gather(sequences, valid_idx)

    # Slice labels (which are lists of tensors) using Python indexing
    y_train = [labels[i] for i in indices[:train_samples]]
    y_valid = [labels[i] for i in indices[train_samples:]]

    return x_train, x_valid, y_train, y_valid

# Ensure padded_sequences is a TensorFlow tensor
padded_sequences_tensor = tf.convert_to_tensor(padded_sequences)

# Apply the fixed split_data function
X_train, X_test, y_train, y_test = split_data(padded_sequences_tensor, filtered_labels)

# Check types to confirm they remain unchanged
print(type(X_train), type(y_train))  # Expected: (tensorflow.Tensor, list)
print(type(X_test), type(y_test))    # Expected: (tensorflow.Tensor, list)
# Out:
# <class 'tensorflow.python.framework.ops.EagerTensor'> <class 'list'>
# <class 'tensorflow.python.framework.ops.EagerTensor'> <class 'list'>

# %%
''' for seq, label in zip(padded_sequences, filtered_labels):
    print(f"Sequence Shape: {seq.shape}, Label: {label}") '''
# Out:
# ' for seq, label in zip(padded_sequences, filtered_labels):\n    print(f"Sequence Shape: {seq.shape}, Label: {label}") '

# %%
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {len(y_train)}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {len(y_test)}")
# Out:
# X_train shape: (2165, 48, 10)
# y_train shape: 2165
# X_test shape: (929, 48, 10)
# y_test shape: 929

# %% [markdown]
# # **Define CTC Loss**

# %%
def ctc_loss(y_true, y_pred):
    # Transpose y_pred if using logits_time_major=True (to [max_time, batch_size, num_classes])
    y_pred = tf.transpose(y_pred, [1, 0, 2])

    # Ensure y_true is of type int32 (or another allowed type)
    y_true = tf.cast(y_true, tf.int32)  # Cast to int32

    # Calculate input length (logit length) and label length
    logit_length = tf.fill([tf.shape(y_pred)[1]], tf.shape(y_pred)[0])  # shape: (batch_size,)
    label_length = tf.reduce_sum(tf.cast(tf.not_equal(y_true, 0), tf.int32), axis=1)  # shape: (batch_size,)

    # Compute the CTC loss using tf.nn.ctc_loss
    loss = tf.nn.ctc_loss(
        labels=y_true,
        logits=y_pred,
        label_length=label_length,
        logit_length=logit_length,
        logits_time_major=True,
        blank_index=0
    )

    ''' # Debugging shapes
    print("y_true shape:", y_true.shape)
    print("y_pred shape:", y_pred.shape)
    print("logit_length shape:", logit_length.shape)
    print("label_length shape:", label_length.shape) '''

    return loss

# %% [markdown]
# # **Common Model Processing**

# %%
from keras.callbacks import EarlyStopping

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

from tensorflow.keras.callbacks import LearningRateScheduler

# Define a learning rate scheduler function
def scheduler(epoch, lr):
  if epoch < 10:
    return float(lr)
  else:
    return float(lr * tf.math.exp(-0.1))

# Create the learning rate scheduler callback
lr_scheduler = LearningRateScheduler(scheduler)

# %%
batch_size = 32

# Prepare the data with the correctly padded labels
train_data = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(batch_size).prefetch(tf.data.AUTOTUNE)
valid_data = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(batch_size).prefetch(tf.data.AUTOTUNE)

# Check shapes before training
for x_batch, y_batch in train_data.take(1):
    print("Batch X shape:", x_batch.shape)  # Expected: (batch_size, time_steps, features)
    print("Batch Y shape:", y_batch.shape)  # Expected: (batch_size, max_label_length)
# Out:
# Batch X shape: (32, 48, 10)
# Batch Y shape: (32, 1)

# %%
# Input shape and number of classes
input_shape = (X_train.shape[1], X_train.shape[2])  # (time_steps, features)
num_classes = len(char_to_num.get_vocabulary()) + 1  # Include the blank token (0 index)

print("Input shape:", input_shape)
print("Number of classes:", num_classes)
# Out:
# Input shape: (48, 10)
# Number of classes: 64

# %% [markdown]
# # **Step 3: CNN Model Design**

# %%
from tensorflow import keras
from tensorflow.keras import layers, models
from keras.optimizers import Adam

def build_ctc_cnn_model(input_shape, num_classes):
    model = models.Sequential([
        layers.Input(shape=input_shape),

        layers.Conv1D(1024, kernel_size=5, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling1D(pool_size=2),
        layers.Dropout(0.3),

        layers.Conv1D(512, kernel_size=3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling1D(pool_size=2),
        layers.Dropout(0.3),

        layers.Conv1D(256, kernel_size=3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling1D(pool_size=2),
        layers.Dropout(0.3),

        layers.Conv1D(128, kernel_size=3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling1D(pool_size=2),
        layers.Dropout(0.3),

        # Dense layer without softmax, to provide logits
        layers.Dense(num_classes)
    ])
    return model

# Build the CNN model
ctc_cnn_model = build_ctc_cnn_model(input_shape, num_classes)

# Compile the model with CTC loss
ctc_cnn_model.compile(optimizer='adam', loss=ctc_loss)

# Display the model summary to verify the architecture
ctc_cnn_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 48, 1024)            │          52,224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 48, 1024)            │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 24, 1024)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 24, 1024)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 24, 512)             │       1,573,376 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 24, 512)             │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, 12, 512)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 12, 512)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_2 (Conv1D)                    │ (None, 12, 256)             │         393,472 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 12, 256)             │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_2 (MaxPooling1D)       │ (None, 6, 256)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 6, 256)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_3 (Conv1D)                    │ (None, 6, 128)              │          98,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 6, 128)              │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_3 (MaxPooling1D)       │ (None, 3, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 3, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 3, 64)               │           8,256 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,133,440 (8.14 MB)
#  Trainable params: 2,129,600 (8.12 MB)
#  Non-trainable params: 3,840 (15.00 KB)

# %%
# Train the model
cnn_history = ctc_cnn_model.fit(
    train_data,
    validation_data=valid_data,
    epochs=500,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# Epoch 1/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1524 - val_loss: 4.1961 - learning_rate: 0.0010
# Epoch 2/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.1182 - val_loss: 4.1858 - learning_rate: 0.0010
# Epoch 3/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.1301 - val_loss: 4.1889 - learning_rate: 0.0010
# Epoch 4/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.1348 - val_loss: 4.1873 - learning_rate: 0.0010
# Epoch 5/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.0974 - val_loss: 4.2004 - learning_rate: 0.0010
# Epoch 6/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.0869 - val_loss: 4.2030 - learning_rate: 0.0010
# Epoch 7/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.0884 - val_loss: 4.2195 - learning_rate: 0.0010
# Epoch 8/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.0855 - val_loss: 4.2072 - learning_rate: 0.0010
# Epoch 9/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.0834 - val_loss: 4.2070 - learning_rate: 0.0010
# Epoch 10/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.0765 - val_loss: 4.2321 - learning_rate: 0.0010
# Epoch 11/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.0568 - val_loss: 4.2439 - learning_rate: 9.0484e-04
# Epoch 12/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.0466 - val_loss: 4.2619 - learning_rate: 8.1873e-04

# %% [markdown]
# # **Step 4: CNN Prediction**

# %%
# Generate raw predictions (logits) from the model
logits = ctc_cnn_model.predict(X_test)

print(f"Logits shape: {logits.shape}")  # Expected shape: (batch_size, time_steps, num_classes)

# Use CTC greedy decoder to convert logits to sequences
decoded_predictions, _ = tf.nn.ctc_greedy_decoder(
    tf.transpose(logits, [1, 0, 2]),  # Transpose for time-major format
    tf.fill([tf.shape(logits)[0]], tf.shape(logits)[1])  # Input length
)

# Convert the sparse tensor to dense format
dense_predictions = tf.sparse.to_dense(decoded_predictions[0], default_value=0)

# Convert from numeric indices to characters using `num_to_char` mapping
predicted_texts = [
    ''.join(num_to_char(index).numpy().decode('utf-8') for index in prediction if index > 0)
    for prediction in dense_predictions
]

# Display a few predictions
for i, pred in enumerate(predicted_texts[:5]):
    print(f"Prediction {i+1}: {pred}")

# Convert y_test (true labels) back to readable text
true_texts = [
    ''.join(num_to_char(index).numpy().decode('utf-8') for index in label if index > 0)
    for label in y_test
]

# Display a few comparisons
for i in range(5):
    print(f"True: {true_texts[i]} | Predicted: {predicted_texts[i]}")

# Calculate accuracy or another relevant metric
from sklearn.metrics import accuracy_score

# Since we are working with sequences, a simple accuracy score might not be sufficient.
# You might consider a character-level or sequence-level accuracy.
sequence_accuracy = sum([1 for true, pred in zip(true_texts, predicted_texts) if true == pred]) / len(true_texts)

print(f"Sequence Accuracy: {sequence_accuracy * 100:.2f}%")
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Logits shape: (929, 3, 64)
# Prediction 1: i
# Prediction 2: A
# Prediction 3: A
# Prediction 4: A
# Prediction 5: A
# True: 7 | Predicted: i
# True: W | Predicted: A
# True: X | Predicted: A
# True: w | Predicted: A
# True: Q | Predicted: A
# Sequence Accuracy: 1.29%

# %% [markdown]
# # **Step 3*: CLDNN Model Design**

# %%
from tensorflow.keras import layers, models
import tensorflow as tf

# Define the CLDNN Model without softmax
def create_cldnn_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape, name='input')

    # Convolutional Layers
    x = layers.Conv1D(512, 5, activation='relu', padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling1D(pool_size=2)(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Conv1D(256, 3, activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling1D(pool_size=2)(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Conv1D(128, 3, activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling1D(pool_size=2)(x)
    x = layers.Dropout(0.3)(x)

    # LSTM Layers
    x = layers.Bidirectional(layers.LSTM(64, return_sequences=True, activation='tanh'))(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Bidirectional(layers.LSTM(64, return_sequences=True, activation='tanh'))(x)
    x = layers.Dropout(0.3)(x)

    # Fully Connected Layer
    x = layers.Dense(100, activation='relu')(x)
    x = layers.Dropout(0.3)(x)

    # Linear Output Layer (No activation function)
    outputs = layers.Dense(num_classes)(x)

    # Define the model
    model = models.Model(inputs, outputs, name='CLDNN_Model')
    return model

# Create the CLDNN model
cldnn_model = create_cldnn_model(input_shape, num_classes)

# Compile the model with CTC loss
cldnn_model.compile(optimizer='adam', loss=ctc_loss)

# Display model summary
cldnn_model.summary()
# Out:
# Model: "CLDNN_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)                   │ (None, 48, 10)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_4 (Conv1D)                    │ (None, 48, 512)             │          26,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 48, 512)             │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_4 (MaxPooling1D)       │ (None, 24, 512)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 24, 512)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_5 (Conv1D)                    │ (None, 24, 256)             │         393,472 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 24, 256)             │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_5 (MaxPooling1D)       │ (None, 12, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 12, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_6 (Conv1D)                    │ (None, 12, 128)             │          98,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 12, 128)             │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_6 (MaxPooling1D)       │ (None, 6, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 6, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, 6, 128)              │          98,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 6, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 6, 128)              │          98,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 6, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 6, 100)              │          12,900 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 6, 100)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 6, 64)               │           6,464 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 738,596 (2.82 MB)
#  Trainable params: 736,804 (2.81 MB)
#  Non-trainable params: 1,792 (7.00 KB)

# %%
# Train the model
cldnn_history = cldnn_model.fit(
    train_data,
    validation_data=valid_data,
    epochs=500,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# Epoch 1/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 48ms/step - loss: 10.9365 - val_loss: 4.9489 - learning_rate: 0.0010
# Epoch 2/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 4.5722 - val_loss: 4.6173 - learning_rate: 0.0010
# Epoch 3/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 4.2002 - val_loss: 4.2949 - learning_rate: 0.0010
# Epoch 4/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.1616 - val_loss: 4.1984 - learning_rate: 0.0010
# Epoch 5/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 4.1451 - val_loss: 4.1623 - learning_rate: 0.0010
# Epoch 6/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 4.1240 - val_loss: 4.1167 - learning_rate: 0.0010
# Epoch 7/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 4.0940 - val_loss: 4.0148 - learning_rate: 0.0010
# Epoch 8/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 3.9991 - val_loss: 3.8912 - learning_rate: 0.0010
# Epoch 9/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 3.9018 - val_loss: 3.8006 - learning_rate: 0.0010
# Epoch 10/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 3.8196 - val_loss: 3.6704 - learning_rate: 0.0010
# Epoch 11/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 3.7556 - val_loss: 3.6386 - learning_rate: 9.0484e-04
# Epoch 12/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 3.6445 - val_loss: 3.4986 - learning_rate: 8.1873e-04
# Epoch 13/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 3.5552 - val_loss: 3.4347 - learning_rate: 7.4082e-04
# Epoch 14/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 3.4893 - val_loss: 3.4126 - learning_rate: 6.7032e-04
# Epoch 15/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 3.4292 - val_loss: 3.3805 - learning_rate: 6.0653e-04
# Epoch 16/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 3.3688 - val_loss: 3.3124 - learning_rate: 5.4881e-04
# Epoch 17/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 3.2773 - val_loss: 3.3077 - learning_rate: 4.9659e-04
# Epoch 18/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 3.2834 - val_loss: 3.2281 - learning_rate: 4.4933e-04
# Epoch 19/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 3.1918 - val_loss: 3.1947 - learning_rate: 4.0657e-04
# Epoch 20/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 3.1541 - val_loss: 3.1523 - learning_rate: 3.6788e-04
# Epoch 21/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 3.1216 - val_loss: 3.1277 - learning_rate: 3.3287e-04
# Epoch 22/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 3.0748 - val_loss: 3.0979 - learning_rate: 3.0119e-04
# Epoch 23/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 3.0291 - val_loss: 3.0702 - learning_rate: 2.7253e-04
# Epoch 24/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.9736 - val_loss: 3.0256 - learning_rate: 2.4660e-04
# Epoch 25/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.9877 - val_loss: 2.9816 - learning_rate: 2.2313e-04
# Epoch 26/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.9109 - val_loss: 2.9512 - learning_rate: 2.0190e-04
# Epoch 27/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.8603 - val_loss: 2.9302 - learning_rate: 1.8268e-04
# Epoch 28/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.8508 - val_loss: 2.9081 - learning_rate: 1.6530e-04
# Epoch 29/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.8246 - val_loss: 2.8807 - learning_rate: 1.4957e-04
# Epoch 30/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.7854 - val_loss: 2.8703 - learning_rate: 1.3534e-04
# Epoch 31/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.7474 - val_loss: 2.8634 - learning_rate: 1.2246e-04
# Epoch 32/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.7368 - val_loss: 2.8414 - learning_rate: 1.1080e-04
# Epoch 33/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.6860 - val_loss: 2.8101 - learning_rate: 1.0026e-04
# Epoch 34/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.6943 - val_loss: 2.8046 - learning_rate: 9.0718e-05
# Epoch 35/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.6555 - val_loss: 2.7971 - learning_rate: 8.2085e-05
# Epoch 36/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.6789 - val_loss: 2.7838 - learning_rate: 7.4273e-05
# Epoch 37/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.6274 - val_loss: 2.7845 - learning_rate: 6.7205e-05
# Epoch 38/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.6410 - val_loss: 2.7805 - learning_rate: 6.0810e-05
# Epoch 39/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.6110 - val_loss: 2.7797 - learning_rate: 5.5023e-05
# Epoch 40/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.5849 - val_loss: 2.7606 - learning_rate: 4.9787e-05
# Epoch 41/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.6018 - val_loss: 2.7582 - learning_rate: 4.5049e-05
# Epoch 42/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.5630 - val_loss: 2.7523 - learning_rate: 4.0762e-05
# Epoch 43/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.5508 - val_loss: 2.7514 - learning_rate: 3.6883e-05
# Epoch 44/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.5898 - val_loss: 2.7476 - learning_rate: 3.3373e-05
# Epoch 45/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.5925 - val_loss: 2.7398 - learning_rate: 3.0197e-05
# Epoch 46/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.5847 - val_loss: 2.7347 - learning_rate: 2.7324e-05
# Epoch 47/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.5327 - val_loss: 2.7363 - learning_rate: 2.4723e-05
# Epoch 48/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.5407 - val_loss: 2.7340 - learning_rate: 2.2371e-05
# Epoch 49/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.5654 - val_loss: 2.7314 - learning_rate: 2.0242e-05
# Epoch 50/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.5296 - val_loss: 2.7308 - learning_rate: 1.8316e-05
# Epoch 51/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.5354 - val_loss: 2.7245 - learning_rate: 1.6573e-05
# Epoch 52/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.5394 - val_loss: 2.7253 - learning_rate: 1.4996e-05
# Epoch 53/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.5100 - val_loss: 2.7233 - learning_rate: 1.3569e-05
# Epoch 54/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.5085 - val_loss: 2.7229 - learning_rate: 1.2277e-05
# Epoch 55/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.5306 - val_loss: 2.7220 - learning_rate: 1.1109e-05
# Epoch 56/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.5490 - val_loss: 2.7220 - learning_rate: 1.0052e-05
# Epoch 57/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.5156 - val_loss: 2.7224 - learning_rate: 9.0953e-06
# Epoch 58/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 2.5398 - val_loss: 2.7207 - learning_rate: 8.2297e-06
# Epoch 59/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 2.4939 - val_loss: 2.7200 - learning_rate: 7.4466e-06
# Epoch 60/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 2.4868 - val_loss: 2.7172 - learning_rate: 6.7379e-06
# Epoch 61/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 2.5006 - val_loss: 2.7179 - learning_rate: 6.0967e-06
# Epoch 62/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 2.5004 - val_loss: 2.7153 - learning_rate: 5.5165e-06
# Epoch 63/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.5207 - val_loss: 2.7162 - learning_rate: 4.9916e-06
# Epoch 64/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.4961 - val_loss: 2.7160 - learning_rate: 4.5166e-06
# Epoch 65/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.4902 - val_loss: 2.7157 - learning_rate: 4.0868e-06
# Epoch 66/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.5532 - val_loss: 2.7142 - learning_rate: 3.6979e-06
# Epoch 67/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.4955 - val_loss: 2.7143 - learning_rate: 3.3460e-06
# Epoch 68/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.4868 - val_loss: 2.7136 - learning_rate: 3.0275e-06
# Epoch 69/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.5180 - val_loss: 2.7136 - learning_rate: 2.7394e-06
# Epoch 70/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.5086 - val_loss: 2.7122 - learning_rate: 2.4787e-06
# Epoch 71/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.4927 - val_loss: 2.7120 - learning_rate: 2.2429e-06
# Epoch 72/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.5077 - val_loss: 2.7113 - learning_rate: 2.0294e-06
# Epoch 73/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 2.4856 - val_loss: 2.7110 - learning_rate: 1.8363e-06
# Epoch 74/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 2.4920 - val_loss: 2.7114 - learning_rate: 1.6616e-06
# Epoch 75/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.5358 - val_loss: 2.7111 - learning_rate: 1.5034e-06
# Epoch 76/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.4880 - val_loss: 2.7115 - learning_rate: 1.3604e-06
# Epoch 77/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.4908 - val_loss: 2.7109 - learning_rate: 1.2309e-06
# Epoch 78/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 2.5005 - val_loss: 2.7110 - learning_rate: 1.1138e-06
# Epoch 79/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.4871 - val_loss: 2.7109 - learning_rate: 1.0078e-06
# Epoch 80/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.4753 - val_loss: 2.7108 - learning_rate: 9.1188e-07
# Epoch 81/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.5069 - val_loss: 2.7116 - learning_rate: 8.2510e-07
# Epoch 82/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 2.5202 - val_loss: 2.7113 - learning_rate: 7.4658e-07
# Epoch 83/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 2.4808 - val_loss: 2.7108 - learning_rate: 6.7554e-07
# Epoch 84/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 2.4992 - val_loss: 2.7101 - learning_rate: 6.1125e-07
# Epoch 85/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 2.5463 - val_loss: 2.7102 - learning_rate: 5.5308e-07
# Epoch 86/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 2.4808 - val_loss: 2.7104 - learning_rate: 5.0045e-07
# Epoch 87/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.5401 - val_loss: 2.7106 - learning_rate: 4.5283e-07
# Epoch 88/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.4739 - val_loss: 2.7099 - learning_rate: 4.0973e-07
# Epoch 89/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.5166 - val_loss: 2.7109 - learning_rate: 3.7074e-07
# Epoch 90/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 2.5292 - val_loss: 2.7104 - learning_rate: 3.3546e-07
# Epoch 91/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.4806 - val_loss: 2.7104 - learning_rate: 3.0354e-07
# Epoch 92/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.5068 - val_loss: 2.7101 - learning_rate: 2.7465e-07
# Epoch 93/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.5109 - val_loss: 2.7099 - learning_rate: 2.4852e-07
# Epoch 94/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 2.4796 - val_loss: 2.7094 - learning_rate: 2.2487e-07
# Epoch 95/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.5145 - val_loss: 2.7097 - learning_rate: 2.0347e-07
# Epoch 96/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.4951 - val_loss: 2.7092 - learning_rate: 1.8410e-07
# Epoch 97/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.4822 - val_loss: 2.7094 - learning_rate: 1.6659e-07
# Epoch 98/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.4794 - val_loss: 2.7090 - learning_rate: 1.5073e-07
# Epoch 99/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.5229 - val_loss: 2.7095 - learning_rate: 1.3639e-07
# Epoch 100/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.4968 - val_loss: 2.7097 - learning_rate: 1.2341e-07
# Epoch 101/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.5113 - val_loss: 2.7096 - learning_rate: 1.1167e-07
# Epoch 102/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.5144 - val_loss: 2.7099 - learning_rate: 1.0104e-07
# Epoch 103/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.5184 - val_loss: 2.7103 - learning_rate: 9.1424e-08
# Epoch 104/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.5183 - val_loss: 2.7102 - learning_rate: 8.2724e-08
# Epoch 105/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.4719 - val_loss: 2.7096 - learning_rate: 7.4851e-08
# Epoch 106/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.5234 - val_loss: 2.7098 - learning_rate: 6.7728e-08
# Epoch 107/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.5290 - val_loss: 2.7092 - learning_rate: 6.1283e-08
# Epoch 108/500
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.5004 - val_loss: 2.7096 - learning_rate: 5.5451e-08

# %% [markdown]
# # **Step 4*: CLDNN Prediction**

# %%
# Generate predictions using the CLDNN model
logits = cldnn_model.predict(X_test)

# Decode predictions using CTC greedy decoder
decoded_predictions, _ = tf.nn.ctc_greedy_decoder(
    tf.transpose(logits, [1, 0, 2]),  # Transpose for time-major format
    tf.fill([tf.shape(logits)[0]], tf.shape(logits)[1])  # Input length
)

# Convert the sparse tensor to dense format
dense_predictions = tf.sparse.to_dense(decoded_predictions[0], default_value=0)

# Convert from numeric indices to characters using `num_to_char` mapping
predicted_texts = [
    ''.join(num_to_char(index).numpy().decode('utf-8') for index in prediction if index > 0)
    for prediction in dense_predictions
]

''' # Display a few predictions
for i, pred in enumerate(predicted_texts[:5]):
    print(f"Prediction {i+1}: {pred}") '''

# Compare predictions with ground truth
true_texts = [
    ''.join(num_to_char(index).numpy().decode('utf-8') for index in label if index > 0)
    for label in y_test
]

# Display a few comparisons
for i in range(5):
    print(f"True: {true_texts[i]} | Predicted: {predicted_texts[i]}")

# Calculate accuracy or another relevant metric
from sklearn.metrics import accuracy_score

# Since we are working with sequences, a simple accuracy score might not be sufficient.
# You might consider a character-level or sequence-level accuracy.
sequence_accuracy = sum([1 for true, pred in zip(true_texts, predicted_texts) if true == pred]) / len(true_texts)

print(f"Sequence Accuracy: {sequence_accuracy * 100:.2f}%")
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# True: 7 | Predicted: 7
# True: W | Predicted: E
# True: X | Predicted: C
# True: w | Predicted: w
# True: Q | Predicted: r
# Sequence Accuracy: 20.56%

# %% [markdown]
# # **Step 5: Plots**

# %%
# prompt: generate training and validation plots for both models

import matplotlib.pyplot as plt

# CNN model
plt.figure(figsize=(10, 5))
plt.subplot(2, 1, 1)
plt.plot(cnn_history.history['loss'])
plt.plot(cnn_history.history['val_loss'])
plt.title('CNN Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# CLDNN model
plt.figure(figsize=(10, 5))
plt.subplot(2, 1, 2)
plt.plot(cldnn_history.history['loss'])
plt.plot(cldnn_history.history['val_loss'])
plt.title('CLDNN Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %% [markdown]
# # 🔮🔮🔮 **Try New Models** 🔮🔮🔮
